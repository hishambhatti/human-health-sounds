# %% [markdown]
# # Audio Preprocessing
#
# This notebook involves pre-processing the human health audio data, directly from VocalSound, to create audio for the HeAR model to form embeddings, cluster, and visualize the sounds. The code to download the VocalSound data can be found in the Old Notebooks/VocalSound.ipynb notebook. Here, we assume that the data has been downloaded locally.
#
# **Note**: The code for generating spectrograms was inspired by https://github.com/kylemcdonald/AudioNotebooks/blob/master/Generating%20Spectrograms.ipynb. All credit to Kyle McDonald.

# %%
# @title Import Statements

import librosa
import numpy as np
import soundfile as sf
import os
import random
from glob import glob
from IPython.display import Audio, display, Markdown
import librosa.display
import matplotlib.pyplot as plt

# %% [markdown]
# ### Clean up VocalSound data
#
# The VocalSound dataset is messy, providing many sounds that are not interpretable, both by humans and the HeAR embedding model. Here we iterate through all clips, trim any silence, and remove those that are too short or too quiet. Additionally, we cap the length of audio clips to 1 second, so that they can be played one after another in our visualization. In the end, we save our processed audio to audio/audio_processed

# %%
def trim_with_librosa(input_filepath, output_filepath, max_duration=1.0, top_db_threshold=40, min_duration=0.2, rms_threshold=-50):
    # Load the audio file, uses mono (1 channel) and a fixed sample rate (16kHz)
    audio, sr = librosa.load(input_filepath, sr=16000, mono=True)

    original_duration = len(audio) / sr

    # Ignores clips that are too short
    if original_duration < min_duration:
        print(f"WARNING: Audio file {input_filepath} too short ({original_duration:.2f}s). Skipping...")
        return

    # Silence Filtering
    mean_squared_amplitude = np.mean(audio**2)

    if mean_squared_amplitude == 0:
        # Handle entirely silent clips
        rms_loudness = rms_threshold - 10
    else:
        rms_loudness = round(20 * np.log10(np.sqrt(mean_squared_amplitude)))

    if rms_loudness < rms_threshold:
        print(f" WARNING: Audio file {input_filepath} was too quiet ({rms_loudness}). Skipping...")
        return

    # Silence trimming
    # This removes leading and trailing silence that is quieter than 'top_db_threshold'
    core_segment, _ = librosa.effects.trim(audio, top_db=top_db_threshold)
    core_duration = len(core_segment) / sr

    # Dynamic Trimming Logic (Highest energy segment if over max_duration)
    if core_duration > max_duration:

        # If too long, apply the highest energy trim to the core segment
        max_samples = int(max_duration * sr)
        hop_length = int(0.05 * sr) # 50ms hop length

        # Calculate RMS frames for the core segment
        core_rms = librosa.feature.rms(y=core_segment, frame_length=2048, hop_length=hop_length, center=False)[0]

        # Find the loudest max_duration window within the core
        max_energy_sum = -1
        best_start_sample_in_core = 0

        for i in range(len(core_rms)):
            current_start_sample = librosa.frames_to_samples(i, hop_length=hop_length)

            # Check if the max_duration segment fits
            if current_start_sample + max_samples > len(core_segment):
                break

            # Use the core segment for energy calculation
            segment = core_segment[current_start_sample : current_start_sample + max_samples]
            current_energy_sum = np.sum(segment**2)

            if current_energy_sum > max_energy_sum:
                max_energy_sum = current_energy_sum
                best_start_sample_in_core = current_start_sample

        final_trimmed_segment = core_segment[best_start_sample_in_core : best_start_sample_in_core + max_samples]
        result_msg = f"Trimmed Core ({core_duration:.3f}s) -> MAX DURATION ({max_duration}s)."

    else:
        # If short enough, save the entire core segment
        final_trimmed_segment = core_segment
        result_msg = f"Kept natural duration: {core_duration:.3f}s (less than {max_duration}s max)."

    # Save the final audio segment with normalization
    max_abs = np.max(np.abs(final_trimmed_segment))
    if max_abs > 0:
        # Normalize to just below 1.0 to prevent clipping
        final_trimmed_segment = final_trimmed_segment / max_abs * 0.95

    sf.write(output_filepath, final_trimmed_segment, sr)
    print(result_msg)

# %%
SOURCE_DIR = "vs_release_16k/audio_16k"
OUTPUT_DIR = "audio/audio_processed"
MAX_DURATION = 1.0

# Higher value = more aggressive removal of quiet sounds
TOP_DB_THRESHOLD = 40
# Minimum length of active sound required to save the clip.
MIN_ACTIVE_DURATION = 0.2
# Minimum loudness for clip to not be silenced
SILENCE_RMS_THRESHOLD_DB = -50

print("--- Starting Librosa-based Dynamic Audio Trimming and Filtering Process ---")

os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Source Directory: {SOURCE_DIR}")
print(f"Output Directory: {OUTPUT_DIR}")
print(f"Maximum Duration: {MAX_DURATION} seconds")
print(f"Silence Threshold (top_db): {TOP_DB_THRESHOLD} dB")
print(f"Minimum Active Duration to Keep: {MIN_ACTIVE_DURATION} seconds")


# Process all .wav files in the source directory
for filename in os.listdir(SOURCE_DIR):
    if filename.endswith((".wav")):
        print(f"\nProcessing: {filename}")

        input_file = os.path.join(SOURCE_DIR, filename)
        output_file = os.path.join(OUTPUT_DIR, filename)

        # Run the Librosa trimming and filtering function
        trim_with_librosa(input_file, output_file, MAX_DURATION, TOP_DB_THRESHOLD, MIN_ACTIVE_DURATION, SILENCE_RMS_THRESHOLD_DB)

print("\n--- Process Complete ---")
# Out:
# --- Starting Librosa-based Dynamic Audio Trimming and Filtering Process ---
# Source Directory: vs_release_16k/audio_16k
# Output Directory: audio/audio_processed
# Maximum Duration: 1.0 seconds
# Silence Threshold (top_db): 40 dB
# Minimum Active Duration to Keep: 0.2 seconds
#
# Processing: f1236_0_sigh.wav
# Trimmed Core (1.472s) -> MAX DURATION (1.0s).
#
# Processing: f1541_0_throatclearing.wav
# Trimmed Core (2.336s) -> MAX DURATION (1.0s).
#
# Processing: m1679_0_sniff.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: m1783_0_throatclearing.wav
# Trimmed Core (1.856s) -> MAX DURATION (1.0s).
#
# Processing: f1291_0_laughter.wav
# Trimmed Core (2.136s) -> MAX DURATION (1.0s).
#
# Processing: m0209_0_sneeze.wav
# Kept natural duration: 0.608s (less than 1.0s max).
#
# Processing: f1284_0_laughter.wav
# Trimmed Core (1.856s) -> MAX DURATION (1.0s).
#
# Processing: m1037_0_sigh.wav
# Trimmed Core (1.216s) -> MAX DURATION (1.0s).
#
# Processing: m0019_0_cough.wav
# Trimmed Core (2.475s) -> MAX DURATION (1.0s).
#
# Processing: f2769_0_laughter.wav
# Trimmed Core (2.688s) -> MAX DURATION (1.0s).
#
# Processing: m1329_0_sniff.wav
# Trimmed Core (7.456s) -> MAX DURATION (1.0s).
#
# Processing: m2930_0_throatclearing.wav
# Trimmed Core (1.056s) -> MAX DURATION (1.0s).
#
# Processing: f2769_0_sniff.wav
# Trimmed Core (2.304s) -> MAX DURATION (1.0s).
#
# Processing: f1956_2_sneeze.wav
# Trimmed Core (2.272s) -> MAX DURATION (1.0s).
#
# Processing: f0998_0_laughter.wav
# Trimmed Core (6.112s) -> MAX DURATION (1.0s).
#
# Processing: m2523_0_laughter.wav
# Trimmed Core (2.304s) -> MAX DURATION (1.0s).
#
# Processing: m2536_0_laughter.wav
# Trimmed Core (2.693s) -> MAX DURATION (1.0s).
#
# Processing: f2899_0_sniff.wav
# Kept natural duration: 0.384s (less than 1.0s max).
#
# Processing: f1216_0_sneeze.wav
# Trimmed Core (1.440s) -> MAX DURATION (1.0s).
#
# Processing: m1528_0_sigh.wav
# Trimmed Core (4.800s) -> MAX DURATION (1.0s).
#
# Processing: f2985_0_throatclearing.wav
# Trimmed Core (2.731s) -> MAX DURATION (1.0s).
#
# Processing: m1770_0_throatclearing.wav
# Trimmed Core (2.693s) -> MAX DURATION (1.0s).
#
# Processing: f0716_0_sneeze.wav
# Trimmed Core (2.048s) -> MAX DURATION (1.0s).
#
# Processing: f1941_1_sneeze.wav
# Trimmed Core (1.728s) -> MAX DURATION (1.0s).
#
# Processing: m0072_0_throatclearing.wav
# WARNING: Audio file vs_release_16k/audio_16k/m0072_0_throatclearing.wav too short (0.00s). Skipping...
#
# Processing: f0743_0_sneeze.wav
# Trimmed Core (7.189s) -> MAX DURATION (1.0s).
#
# Processing: m1794_0_cough.wav
# Trimmed Core (5.664s) -> MAX DURATION (1.0s).
#
# Processing: m3123_0_cough.wav
# Trimmed Core (3.622s) -> MAX DURATION (1.0s).
#
# Processing: f0511_0_sniff.wav
# Trimmed Core (4.747s) -> MAX DURATION (1.0s).
#
# Processing: f0748_0_sigh.wav
# Trimmed Core (1.120s) -> MAX DURATION (1.0s).
#
# Processing: m0186_0_cough.wav
# Kept natural duration: 0.224s (less than 1.0s max).
#
# Processing: m2743_0_sniff.wav
# Trimmed Core (3.499s) -> MAX DURATION (1.0s).
#
# Processing: m2731_0_cough.wav
# Trimmed Core (6.059s) -> MAX DURATION (1.0s).
#
# Processing: m2047_0_sneeze.wav
# Trimmed Core (2.601s) -> MAX DURATION (1.0s).
#
# Processing: f1303_0_sniff.wav
# Trimmed Core (3.840s) -> MAX DURATION (1.0s).
#
# Processing: m0563_2_cough.wav
# Trimmed Core (1.472s) -> MAX DURATION (1.0s).
#
# Processing: f2684_0_cough.wav
# Trimmed Core (2.368s) -> MAX DURATION (1.0s).
#
# Processing: f1621_0_cough.wav
# Trimmed Core (4.363s) -> MAX DURATION (1.0s).
#
# Processing: m0262_0_laughter.wav
# Trimmed Core (1.536s) -> MAX DURATION (1.0s).
#
# Processing: m2261_0_cough.wav
# Trimmed Core (2.176s) -> MAX DURATION (1.0s).
#
# Processing: m0618_0_throatclearing.wav
# Trimmed Core (2.048s) -> MAX DURATION (1.0s).
#
# Processing: f1653_0_sniff.wav
# Trimmed Core (1.504s) -> MAX DURATION (1.0s).
#
# Processing: f2558_0_sneeze.wav
# Kept natural duration: 0.864s (less than 1.0s max).
#
# Processing: f0028_0_laughter.wav
# Trimmed Core (3.328s) -> MAX DURATION (1.0s).
#
# Processing: m0056_0_sigh.wav
# Trimmed Core (3.735s) -> MAX DURATION (1.0s).
#
# Processing: m1864_0_cough.wav
# Trimmed Core (5.024s) -> MAX DURATION (1.0s).
#
# Processing: m2393_0_sigh.wav
# Trimmed Core (4.352s) -> MAX DURATION (1.0s).
#
# Processing: f2192_0_sigh.wav
# Trimmed Core (9.376s) -> MAX DURATION (1.0s).
#
# Processing: m0587_0_sneeze.wav
# Kept natural duration: 0.837s (less than 1.0s max).
#
# Processing: f2368_0_laughter.wav
# Trimmed Core (4.693s) -> MAX DURATION (1.0s).
#
# Processing: m0973_0_sneeze.wav
# Trimmed Core (1.088s) -> MAX DURATION (1.0s).
#
# Processing: f0627_0_throatclearing.wav
# Trimmed Core (1.408s) -> MAX DURATION (1.0s).
#
# Processing: f1685_0_laughter.wav
# Trimmed Core (2.784s) -> MAX DURATION (1.0s).
#
# Processing: m0882_0_sniff.wav
# Trimmed Core (9.568s) -> MAX DURATION (1.0s).
#
# Processing: f1690_0_laughter.wav
# Trimmed Core (6.240s) -> MAX DURATION (1.0s).
#
# Processing: f0067_0_sneeze.wav
# Trimmed Core (1.344s) -> MAX DURATION (1.0s).
#
# Processing: f1352_0_throatclearing.wav
# Trimmed Core (5.056s) -> MAX DURATION (1.0s).
#
# Processing: f0674_0_laughter.wav
# Trimmed Core (1.600s) -> MAX DURATION (1.0s).
#
# Processing: f1585_0_sniff.wav
# Trimmed Core (2.176s) -> MAX DURATION (1.0s).
#
# Processing: f3340_0_cough.wav
# Trimmed Core (5.408s) -> MAX DURATION (1.0s).
#
# Processing: m0772_0_sniff.wav
# Trimmed Core (2.521s) -> MAX DURATION (1.0s).
#
# Processing: m1190_0_throatclearing.wav
# Trimmed Core (1.877s) -> MAX DURATION (1.0s).
#
# Processing: m0700_0_cough.wav
# Trimmed Core (1.152s) -> MAX DURATION (1.0s).
#
# Processing: f3332_0_sniff.wav
# Trimmed Core (4.779s) -> MAX DURATION (1.0s).
#
# Processing: f0661_0_laughter.wav
# Trimmed Core (1.120s) -> MAX DURATION (1.0s).
#
# Processing: m1762_0_sigh.wav
# Trimmed Core (1.280s) -> MAX DURATION (1.0s).
#
# Processing: f0098_0_sneeze.wav
# WARNING: Audio file vs_release_16k/audio_16k/f0098_0_sneeze.wav too short (0.00s). Skipping...
#
# Processing: f2890_0_laughter.wav
# Trimmed Core (1.664s) -> MAX DURATION (1.0s).
#
# Processing: m1112_0_cough.wav
# Trimmed Core (7.168s) -> MAX DURATION (1.0s).
#
# Processing: f2885_0_laughter.wav
# Trimmed Core (3.157s) -> MAX DURATION (1.0s).
#
# Processing: f2520_0_sniff.wav
# Trimmed Core (4.800s) -> MAX DURATION (1.0s).
#
# Processing: m2137_0_laughter.wav
# Trimmed Core (1.685s) -> MAX DURATION (1.0s).
#
# Processing: m0578_0_sneeze.wav
# Trimmed Core (1.696s) -> MAX DURATION (1.0s).
#
# Processing: m0222_0_sniff.wav
# Trimmed Core (4.267s) -> MAX DURATION (1.0s).
#
# Processing: f0450_0_throatclearing.wav
# Trimmed Core (4.576s) -> MAX DURATION (1.0s).
#
# Processing: m2495_0_sniff.wav
# Trimmed Core (4.149s) -> MAX DURATION (1.0s).
#
# Processing: m0250_0_cough.wav
# Kept natural duration: 0.992s (less than 1.0s max).
#
# Processing: f1939_0_sneeze.wav
# Trimmed Core (8.000s) -> MAX DURATION (1.0s).
#
# Processing: m1442_0_cough.wav
# Trimmed Core (3.456s) -> MAX DURATION (1.0s).
#
# Processing: m2892_0_laughter.wav
# Trimmed Core (2.645s) -> MAX DURATION (1.0s).
#
# Processing: m2887_0_laughter.wav
# Trimmed Core (2.976s) -> MAX DURATION (1.0s).
#
# Processing: f2120_0_laughter.wav
# Trimmed Core (1.536s) -> MAX DURATION (1.0s).
#
# Processing: f1201_0_sigh.wav
# Trimmed Core (2.240s) -> MAX DURATION (1.0s).
#
# Processing: m2763_0_sneeze.wav
# Trimmed Core (1.792s) -> MAX DURATION (1.0s).
#
# Processing: m3263_0_sneeze.wav
# Trimmed Core (3.584s) -> MAX DURATION (1.0s).
#
# Processing: f0208_0_sniff.wav
# Trimmed Core (2.592s) -> MAX DURATION (1.0s).
#
# Processing: f1138_0_cough.wav
# Trimmed Core (3.904s) -> MAX DURATION (1.0s).
#
# Processing: m2578_0_cough.wav
# Trimmed Core (2.464s) -> MAX DURATION (1.0s).
#
# Processing: f1242_1_throatclearing.wav
# Trimmed Core (5.632s) -> MAX DURATION (1.0s).
#
# Processing: m1687_0_laughter.wav
# Kept natural duration: 0.768s (less than 1.0s max).
#
# Processing: m2736_0_sneeze.wav
# Trimmed Core (5.024s) -> MAX DURATION (1.0s).
#
# Processing: m3318_0_sniff.wav
# Trimmed Core (4.523s) -> MAX DURATION (1.0s).
#
# Processing: f1141_0_laughter.wav
# Trimmed Core (2.475s) -> MAX DURATION (1.0s).
#
# Processing: f2086_0_sigh.wav
# Trimmed Core (11.053s) -> MAX DURATION (1.0s).
#
# Processing: f2112_0_sniff.wav
# Trimmed Core (4.704s) -> MAX DURATION (1.0s).
#
# Processing: f1154_0_laughter.wav
# Trimmed Core (5.792s) -> MAX DURATION (1.0s).
#
# Processing: m1520_0_cough.wav
# Trimmed Core (3.221s) -> MAX DURATION (1.0s).
#
# Processing: f3222_0_cough.wav
# Kept natural duration: 0.512s (less than 1.0s max).
#
# Processing: f1949_2_throatclearing.wav
# Kept natural duration: 0.800s (less than 1.0s max).
#
# Processing: f1495_0_cough.wav
# Trimmed Core (5.056s) -> MAX DURATION (1.0s).
#
# Processing: m0662_0_cough.wav
# Trimmed Core (6.827s) -> MAX DURATION (1.0s).
#
# Processing: m1002_0_sniff.wav
# Trimmed Core (2.656s) -> MAX DURATION (1.0s).
#
# Processing: m0142_0_sigh.wav
# Trimmed Core (4.011s) -> MAX DURATION (1.0s).
#
# Processing: f0287_0_cough.wav
# Trimmed Core (3.328s) -> MAX DURATION (1.0s).
#
# Processing: f0110_0_sneeze.wav
# Trimmed Core (3.065s) -> MAX DURATION (1.0s).
#
# Processing: m0817_0_laughter.wav
# Trimmed Core (1.024s) -> MAX DURATION (1.0s).
#
# Processing: m3338_0_throatclearing.wav
# Trimmed Core (1.472s) -> MAX DURATION (1.0s).
#
# Processing: f2599_0_sigh.wav
# Trimmed Core (7.989s) -> MAX DURATION (1.0s).
#
# Processing: f1440_0_sigh.wav
# Trimmed Core (2.240s) -> MAX DURATION (1.0s).
#
# Processing: f0827_0_cough.wav
# Kept natural duration: 0.768s (less than 1.0s max).
#
# Processing: m1641_0_sigh.wav
# Trimmed Core (4.277s) -> MAX DURATION (1.0s).
#
# Processing: m2468_0_sniff.wav
# Kept natural duration: 0.896s (less than 1.0s max).
#
# Processing: f1028_0_sniff.wav
# Trimmed Core (4.087s) -> MAX DURATION (1.0s).
#
# Processing: m3341_0_sneeze.wav
# Trimmed Core (1.344s) -> MAX DURATION (1.0s).
#
# Processing: f0815_0_laughter.wav
# Trimmed Core (3.622s) -> MAX DURATION (1.0s).
#
# Processing: f0800_0_laughter.wav
# Trimmed Core (2.560s) -> MAX DURATION (1.0s).
#
# Processing: m0965_0_throatclearing.wav
# Trimmed Core (2.656s) -> MAX DURATION (1.0s).
#
# Processing: m2138_0_sniff.wav
# Trimmed Core (5.120s) -> MAX DURATION (1.0s).
#
# Processing: f1309_0_laughter.wav
# Trimmed Core (2.322s) -> MAX DURATION (1.0s).
#
# Processing: f0421_0_sigh.wav
# Trimmed Core (2.955s) -> MAX DURATION (1.0s).
#
# Processing: f1578_0_sniff.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: m3314_0_sneeze.wav
# Trimmed Core (1.760s) -> MAX DURATION (1.0s).
#
# Processing: m0620_0_sigh.wav
# Trimmed Core (4.375s) -> MAX DURATION (1.0s).
#
# Processing: f2092_0_throatclearing.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: f0923_0_throatclearing.wav
# Trimmed Core (1.984s) -> MAX DURATION (1.0s).
#
# Processing: m1143_0_laughter.wav
# Trimmed Core (4.661s) -> MAX DURATION (1.0s).
#
# Processing: m0996_0_throatclearing.wav
# Trimmed Core (4.128s) -> MAX DURATION (1.0s).
#
# Processing: f1322_0_sigh.wav
# Kept natural duration: 0.864s (less than 1.0s max).
#
# Processing: m1123_0_sigh.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: f1334_0_sneeze.wav
# Trimmed Core (2.016s) -> MAX DURATION (1.0s).
#
# Processing: m1681_0_sneeze.wav
# Trimmed Core (3.936s) -> MAX DURATION (1.0s).
#
# Processing: m3203_0_laughter.wav
# Trimmed Core (1.792s) -> MAX DURATION (1.0s).
#
# Processing: f0109_0_sigh.wav
# Trimmed Core (3.232s) -> MAX DURATION (1.0s).
#
# Processing: f2989_0_cough.wav
# Trimmed Core (3.360s) -> MAX DURATION (1.0s).
#
# Processing: f1361_0_sneeze.wav
# Trimmed Core (5.824s) -> MAX DURATION (1.0s).
#
# Processing: f0661_0_sneeze.wav
# Kept natural duration: 0.832s (less than 1.0s max).
#
# Processing: f1315_0_sigh.wav
# Trimmed Core (2.069s) -> MAX DURATION (1.0s).
#
# Processing: m2229_0_throatclearing.wav
# Trimmed Core (1.984s) -> MAX DURATION (1.0s).
#
# Processing: m0308_0_sigh.wav
# Trimmed Core (2.219s) -> MAX DURATION (1.0s).
#
# Processing: f1540_0_laughter.wav
# Trimmed Core (1.152s) -> MAX DURATION (1.0s).
#
# Processing: m1114_0_sigh.wav
# Trimmed Core (4.864s) -> MAX DURATION (1.0s).
#
# Processing: f2679_0_cough.wav
# Trimmed Core (3.136s) -> MAX DURATION (1.0s).
#
# Processing: m0459_0_sniff.wav
# Trimmed Core (2.528s) -> MAX DURATION (1.0s).
#
# Processing: f3019_0_sniff.wav
# Trimmed Core (3.637s) -> MAX DURATION (1.0s).
#
# Processing: f0416_0_sigh.wav
# Kept natural duration: 0.928s (less than 1.0s max).
#
# Processing: m1769_0_cough.wav
# Trimmed Core (5.248s) -> MAX DURATION (1.0s).
#
# Processing: f3049_0_laughter.wav
# Trimmed Core (2.688s) -> MAX DURATION (1.0s).
#
# Processing: m1906_0_cough.wav
# Trimmed Core (3.936s) -> MAX DURATION (1.0s).
#
# Processing: m2634_0_throatclearing.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: m1887_0_throatclearing.wav
# Trimmed Core (2.304s) -> MAX DURATION (1.0s).
#
# Processing: f2672_0_throatclearing.wav
# Trimmed Core (1.760s) -> MAX DURATION (1.0s).
#
# Processing: m3136_0_throatclearing.wav
# Trimmed Core (4.896s) -> MAX DURATION (1.0s).
#
# Processing: m1676_0_sigh.wav
# Trimmed Core (3.808s) -> MAX DURATION (1.0s).
#
# Processing: f0151_0_cough.wav
# Trimmed Core (2.336s) -> MAX DURATION (1.0s).
#
# Processing: f2794_0_sniff.wav
# Trimmed Core (2.816s) -> MAX DURATION (1.0s).
#
# Processing: m2165_0_sneeze.wav
# Trimmed Core (1.280s) -> MAX DURATION (1.0s).
#
# Processing: m2371_0_sniff.wav
# Trimmed Core (1.984s) -> MAX DURATION (1.0s).
#
# Processing: f3186_0_sniff.wav
# Trimmed Core (2.080s) -> MAX DURATION (1.0s).
#
# Processing: m3341_0_throatclearing.wav
# Trimmed Core (2.496s) -> MAX DURATION (1.0s).
#
# Processing: m2303_0_cough.wav
# Trimmed Core (1.312s) -> MAX DURATION (1.0s).
#
# Processing: f3183_0_throatclearing.wav
# Trimmed Core (1.824s) -> MAX DURATION (1.0s).
#
# Processing: m1557_0_laughter.wav
# Trimmed Core (3.200s) -> MAX DURATION (1.0s).
#
# Processing: f0401_0_cough.wav
# Trimmed Core (5.568s) -> MAX DURATION (1.0s).
#
# Processing: m2130_0_sneeze.wav
# Kept natural duration: 0.832s (less than 1.0s max).
#
# Processing: m1542_0_laughter.wav
# Trimmed Core (6.496s) -> MAX DURATION (1.0s).
#
# Processing: m3041_0_cough.wav
# Trimmed Core (2.336s) -> MAX DURATION (1.0s).
#
# Processing: m1684_0_sniff.wav
# Trimmed Core (6.741s) -> MAX DURATION (1.0s).
#
# Processing: m2621_0_sniff.wav
# Trimmed Core (5.461s) -> MAX DURATION (1.0s).
#
# Processing: f3185_0_sneeze.wav
# Trimmed Core (1.824s) -> MAX DURATION (1.0s).
#
# Processing: f2908_0_laughter.wav
# Trimmed Core (2.336s) -> MAX DURATION (1.0s).
#
# Processing: m0175_0_sigh.wav
# Trimmed Core (5.717s) -> MAX DURATION (1.0s).
#
# Processing: f1261_0_sniff.wav
# Trimmed Core (5.024s) -> MAX DURATION (1.0s).
#
# Processing: m2653_0_cough.wav
#  WARNING: Audio file vs_release_16k/audio_16k/m2653_0_cough.wav was too quiet (-71). Skipping...
#
# Processing: m1228_0_sigh.wav
# Trimmed Core (2.357s) -> MAX DURATION (1.0s).
#
# Processing: m0034_0_sigh.wav
# Trimmed Core (1.120s) -> MAX DURATION (1.0s).
#
# Processing: f0711_0_sneeze.wav
# Trimmed Core (3.936s) -> MAX DURATION (1.0s).
#
# Processing: f1387_0_laughter.wav
# Trimmed Core (5.024s) -> MAX DURATION (1.0s).
#
# Processing: f1392_0_laughter.wav
# Trimmed Core (3.552s) -> MAX DURATION (1.0s).
#
# Processing: m0129_0_laughter.wav
# Trimmed Core (2.357s) -> MAX DURATION (1.0s).
#
# Processing: f1244_0_sneeze.wav
# Trimmed Core (3.584s) -> MAX DURATION (1.0s).
#
# Processing: f0888_0_throatclearing.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: m1737_0_sigh.wav
# Trimmed Core (2.080s) -> MAX DURATION (1.0s).
#
# Processing: m0069_0_cough.wav
# Trimmed Core (1.408s) -> MAX DURATION (1.0s).
#
# Processing: m1609_0_sniff.wav
# Trimmed Core (6.176s) -> MAX DURATION (1.0s).
#
# Processing: m2435_0_laughter.wav
# Trimmed Core (3.744s) -> MAX DURATION (1.0s).
#
# Processing: m2420_0_laughter.wav
# Trimmed Core (3.157s) -> MAX DURATION (1.0s).
#
# Processing: f2249_0_sniff.wav
#  WARNING: Audio file vs_release_16k/audio_16k/f2249_0_sniff.wav was too quiet (-51). Skipping...
#
# Processing: f2861_0_sigh.wav
# Trimmed Core (3.925s) -> MAX DURATION (1.0s).
#
# Processing: m0539_0_cough.wav
# Trimmed Core (2.383s) -> MAX DURATION (1.0s).
#
# Processing: m1359_0_sniff.wav
# Kept natural duration: 0.832s (less than 1.0s max).
#
# Processing: m2308_0_throatclearing.wav
# Trimmed Core (1.760s) -> MAX DURATION (1.0s).
#
# Processing: f2422_0_laughter.wav
# Trimmed Core (4.011s) -> MAX DURATION (1.0s).
#
# Processing: f2524_0_throatclearing.wav
# Trimmed Core (3.328s) -> MAX DURATION (1.0s).
#
# Processing: f1913_0_throatclearing.wav
# Kept natural duration: 0.992s (less than 1.0s max).
#
# Processing: f2904_0_cough.wav
# Trimmed Core (1.184s) -> MAX DURATION (1.0s).
#
# Processing: m0374_0_laughter.wav
# Trimmed Core (3.232s) -> MAX DURATION (1.0s).
#
# Processing: m0361_0_laughter.wav
# Trimmed Core (7.840s) -> MAX DURATION (1.0s).
#
# Processing: m2562_0_throatclearing.wav
#  WARNING: Audio file vs_release_16k/audio_16k/m2562_0_throatclearing.wav was too quiet (-55). Skipping...
#
# Processing: m1955_0_throatclearing.wav
# Trimmed Core (3.232s) -> MAX DURATION (1.0s).
#
# Processing: m2493_0_sigh.wav
# Trimmed Core (1.950s) -> MAX DURATION (1.0s).
#
# Processing: m2733_0_sniff.wav
# Trimmed Core (4.864s) -> MAX DURATION (1.0s).
#
# Processing: m2715_0_throatclearing.wav
# Trimmed Core (4.128s) -> MAX DURATION (1.0s).
#
# Processing: m3293_0_throatclearing.wav
#  WARNING: Audio file vs_release_16k/audio_16k/m3293_0_throatclearing.wav was too quiet (-96). Skipping...
#
# Processing: f1301_0_cough.wav
# Trimmed Core (3.808s) -> MAX DURATION (1.0s).
#
# Processing: m0249_0_sigh.wav
# Trimmed Core (7.552s) -> MAX DURATION (1.0s).
#
# Processing: m0184_0_sniff.wav
# Trimmed Core (3.251s) -> MAX DURATION (1.0s).
#
# Processing: m2741_0_cough.wav
# Trimmed Core (3.040s) -> MAX DURATION (1.0s).
#
# Processing: m3121_0_sniff.wav
# Trimmed Core (6.016s) -> MAX DURATION (1.0s).
#
# Processing: f2901_0_sneeze.wav
# Trimmed Core (8.824s) -> MAX DURATION (1.0s).
#
# Processing: f0513_0_cough.wav
# Trimmed Core (9.152s) -> MAX DURATION (1.0s).
#
# Processing: f1254_0_sigh.wav
# Trimmed Core (1.472s) -> MAX DURATION (1.0s).
#
# Processing: m3153_0_cough.wav
# Trimmed Core (3.552s) -> MAX DURATION (1.0s).
#
# Processing: m2263_0_sniff.wav
# Trimmed Core (2.272s) -> MAX DURATION (1.0s).
#
# Processing: m2591_0_throatclearing.wav
# Trimmed Core (1.600s) -> MAX DURATION (1.0s).
#
# Processing: m3017_0_throatclearing.wav
# Trimmed Core (4.000s) -> MAX DURATION (1.0s).
#
# Processing: f3094_0_sniff.wav
# Trimmed Core (2.400s) -> MAX DURATION (1.0s).
#
# Processing: f1651_0_cough.wav
# Trimmed Core (4.384s) -> MAX DURATION (1.0s).
#
# Processing: m2015_0_sneeze.wav
# Trimmed Core (3.712s) -> MAX DURATION (1.0s).
#
# Processing: f0043_0_cough.wav
# Trimmed Core (3.040s) -> MAX DURATION (1.0s).
#
# Processing: f2686_0_sniff.wav
# Trimmed Core (8.608s) -> MAX DURATION (1.0s).
#
# Processing: m1062_0_sigh.wav
# Trimmed Core (3.744s) -> MAX DURATION (1.0s).
#
# Processing: f2522_0_cough.wav
# Trimmed Core (1.120s) -> MAX DURATION (1.0s).
#
# Processing: m1162_0_cough.wav
# Trimmed Core (1.312s) -> MAX DURATION (1.0s).
#
# Processing: m0702_0_sniff.wav
# Trimmed Core (1.088s) -> MAX DURATION (1.0s).
#
# Processing: f1587_0_cough.wav
# Trimmed Core (4.576s) -> MAX DURATION (1.0s).
#
# Processing: m0770_0_cough.wav
# Trimmed Core (8.736s) -> MAX DURATION (1.0s).
#
# Processing: m3285_0_cough.wav
# Trimmed Core (3.499s) -> MAX DURATION (1.0s).
#
# Processing: m1432_0_cough.wav
# Trimmed Core (1.376s) -> MAX DURATION (1.0s).
#
# Processing: m0252_0_sniff.wav
# Trimmed Core (2.645s) -> MAX DURATION (1.0s).
#
# Processing: m0528_0_laughter.wav
# Trimmed Core (3.712s) -> MAX DURATION (1.0s).
#
# Processing: m0220_0_cough.wav
# Trimmed Core (1.984s) -> MAX DURATION (1.0s).
#
# Processing: f1786_0_laughter.wav
# Trimmed Core (7.136s) -> MAX DURATION (1.0s).
#
# Processing: f2986_0_laughter.wav
# Trimmed Core (2.304s) -> MAX DURATION (1.0s).
#
# Processing: f2993_0_laughter.wav
# Trimmed Core (3.616s) -> MAX DURATION (1.0s).
#
# Processing: m0761_0_sigh.wav
# Trimmed Core (4.768s) -> MAX DURATION (1.0s).
#
# Processing: m0580_0_sneeze.wav
# Trimmed Core (1.280s) -> MAX DURATION (1.0s).
#
# Processing: m1080_0_sneeze.wav
# Trimmed Core (1.216s) -> MAX DURATION (1.0s).
#
# Processing: f0777_0_laughter.wav
# Trimmed Core (3.648s) -> MAX DURATION (1.0s).
#
# Processing: f0060_0_sneeze.wav
# Trimmed Core (2.016s) -> MAX DURATION (1.0s).
#
# Processing: f1994_0_sneeze.wav
# Kept natural duration: 0.640s (less than 1.0s max).
#
# Processing: f1560_0_sneeze.wav
# Kept natural duration: 0.576s (less than 1.0s max).
#
# Processing: m2021_0_laughter.wav
# Trimmed Core (5.280s) -> MAX DURATION (1.0s).
#
# Processing: m2034_0_laughter.wav
# Trimmed Core (6.944s) -> MAX DURATION (1.0s).
#
# Processing: m0921_0_sneeze.wav
# Kept natural duration: 0.928s (less than 1.0s max).
#
# Processing: m0880_0_cough.wav
# Trimmed Core (1.376s) -> MAX DURATION (1.0s).
#
# Processing: m0760_0_laughter.wav
# Trimmed Core (1.696s) -> MAX DURATION (1.0s).
#
# Processing: f0278_0_sniff.wav
# Trimmed Core (6.485s) -> MAX DURATION (1.0s).
#
# Processing: m2991_0_laughter.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: m2058_0_cough.wav
# Trimmed Core (2.304s) -> MAX DURATION (1.0s).
#
# Processing: f2023_0_laughter.wav
# Trimmed Core (4.096s) -> MAX DURATION (1.0s).
#
# Processing: m2731_0_sneeze.wav
# Trimmed Core (1.184s) -> MAX DURATION (1.0s).
#
# Processing: m2382_0_throatclearing.wav
# Trimmed Core (4.192s) -> MAX DURATION (1.0s).
#
# Processing: f0728_0_sniff.wav
# Trimmed Core (1.472s) -> MAX DURATION (1.0s).
#
# Processing: o0005_0_sniff.wav
# Trimmed Core (6.656s) -> MAX DURATION (1.0s).
#
# Processing: f2036_0_laughter.wav
# Trimmed Core (2.880s) -> MAX DURATION (1.0s).
#
# Processing: f1148_0_cough.wav
# Trimmed Core (2.720s) -> MAX DURATION (1.0s).
#
# Processing: f2337_0_throatclearing.wav
# Trimmed Core (2.688s) -> MAX DURATION (1.0s).
#
# Processing: m0844_0_throatclearing.wav
# Trimmed Core (5.696s) -> MAX DURATION (1.0s).
#
# Processing: m1791_0_laughter.wav
# Trimmed Core (5.312s) -> MAX DURATION (1.0s).
#
# Processing: m1784_0_laughter.wav
# Trimmed Core (2.720s) -> MAX DURATION (1.0s).
#
# Processing: f0802_0_throatclearing.wav
# Trimmed Core (3.270s) -> MAX DURATION (1.0s).
#
# Processing: m2371_0_throatclearing.wav
# Trimmed Core (1.024s) -> MAX DURATION (1.0s).
#
# Processing: f2299_0_sigh.wav
# Trimmed Core (3.065s) -> MAX DURATION (1.0s).
#
# Processing: m1623_1_sigh.wav
# Trimmed Core (3.808s) -> MAX DURATION (1.0s).
#
# Processing: m0537_0_throatclearing.wav
# Trimmed Core (4.949s) -> MAX DURATION (1.0s).
#
# Processing: f3085_0_sigh.wav
# Trimmed Core (1.664s) -> MAX DURATION (1.0s).
#
# Processing: f1042_0_laughter.wav
# Trimmed Core (3.339s) -> MAX DURATION (1.0s).
#
# Processing: f1273_0_throatclearing.wav
# Trimmed Core (3.808s) -> MAX DURATION (1.0s).
#
# Processing: f0117_0_sneeze.wav
# Kept natural duration: 0.416s (less than 1.0s max).
#
# Processing: m3284_0_sigh.wav
#  WARNING: Audio file vs_release_16k/audio_16k/m3284_0_sigh.wav was too quiet (-96). Skipping...
#
# Processing: f0571_0_throatclearing.wav
# Trimmed Core (1.920s) -> MAX DURATION (1.0s).
#
# Processing: m0803_0_sneeze.wav
# Trimmed Core (1.120s) -> MAX DURATION (1.0s).
#
# Processing: m1235_0_throatclearing.wav
# Trimmed Core (3.168s) -> MAX DURATION (1.0s).
#
# Processing: f1340_0_sigh.wav
# Trimmed Core (1.888s) -> MAX DURATION (1.0s).
#
# Processing: f2110_0_cough.wav
# Trimmed Core (8.864s) -> MAX DURATION (1.0s).
#
# Processing: m1522_0_sniff.wav
# Trimmed Core (2.645s) -> MAX DURATION (1.0s).
#
# Processing: m1550_0_cough.wav
# Trimmed Core (2.176s) -> MAX DURATION (1.0s).
#
# Processing: f2162_0_sniff.wav
# Trimmed Core (1.728s) -> MAX DURATION (1.0s).
#
# Processing: m2909_0_sigh.wav
# Trimmed Core (10.208s) -> MAX DURATION (1.0s).
#
# Processing: f1849_0_sneeze.wav
# Trimmed Core (2.816s) -> MAX DURATION (1.0s).
#
# Processing: m0342_0_cough.wav
# Trimmed Core (1.856s) -> MAX DURATION (1.0s).
#
# Processing: m0914_0_laughter.wav
# Trimmed Core (5.128s) -> MAX DURATION (1.0s).
#
# Processing: f0706_0_throatclearing.wav
# Kept natural duration: 0.544s (less than 1.0s max).
#
# Processing: f1280_0_throatclearing.wav
# Trimmed Core (1.611s) -> MAX DURATION (1.0s).
#
# Processing: f0285_0_sniff.wav
# Trimmed Core (2.415s) -> MAX DURATION (1.0s).
#
# Processing: m1072_0_sniff.wav
# Trimmed Core (2.656s) -> MAX DURATION (1.0s).
#
# Processing: m1208_0_laughter.wav
# Trimmed Core (1.472s) -> MAX DURATION (1.0s).
#
# Processing: f0443_0_sigh.wav
# Kept natural duration: 0.864s (less than 1.0s max).
#
# Processing: m0660_0_sniff.wav
# Trimmed Core (2.496s) -> MAX DURATION (1.0s).
#
# Processing: f1004_0_throatclearing.wav
# Kept natural duration: 0.928s (less than 1.0s max).
#
# Processing: m0612_0_cough.wav
# Trimmed Core (5.184s) -> MAX DURATION (1.0s).
#
# Processing: f3220_0_sniff.wav
# Trimmed Core (2.005s) -> MAX DURATION (1.0s).
#
# Processing: f2359_0_sneeze.wav
# Trimmed Core (1.984s) -> MAX DURATION (1.0s).
#
# Processing: f0916_0_laughter.wav
# Trimmed Core (6.624s) -> MAX DURATION (1.0s).
#
# Processing: m1623_0_sigh.wav
# Trimmed Core (3.344s) -> MAX DURATION (1.0s).
#
# Processing: f0638_0_cough.wav
# Trimmed Core (5.248s) -> MAX DURATION (1.0s).
#
# Processing: m3278_0_cough.wav
# Trimmed Core (1.600s) -> MAX DURATION (1.0s).
#
# Processing: m2418_0_sniff.wav
# Trimmed Core (5.472s) -> MAX DURATION (1.0s).
#
# Processing: m1040_0_laughter.wav
# Trimmed Core (4.352s) -> MAX DURATION (1.0s).
#
# Processing: m0120_0_sigh.wav
# Trimmed Core (5.294s) -> MAX DURATION (1.0s).
#
# Processing: f0368_0_cough.wav
# Trimmed Core (1.856s) -> MAX DURATION (1.0s).
#
# Processing: m2613_0_sneeze.wav
# Trimmed Core (2.879s) -> MAX DURATION (1.0s).
#
# Processing: m3313_0_sneeze.wav
# Trimmed Core (1.792s) -> MAX DURATION (1.0s).
#
# Processing: f1508_0_sniff.wav
# Trimmed Core (4.064s) -> MAX DURATION (1.0s).
#
# Processing: m3300_0_laughter.wav
# Trimmed Core (5.664s) -> MAX DURATION (1.0s).
#
# Processing: m0429_0_sniff.wav
# Trimmed Core (3.104s) -> MAX DURATION (1.0s).
#
# Processing: m3315_0_laughter.wav
# Trimmed Core (1.728s) -> MAX DURATION (1.0s).
#
# Processing: f3069_0_sniff.wav
# Trimmed Core (1.664s) -> MAX DURATION (1.0s).
#
# Processing: f2609_0_cough.wav
# Trimmed Core (6.400s) -> MAX DURATION (1.0s).
#
# Processing: f3111_1_sniff.wav
# Trimmed Core (4.416s) -> MAX DURATION (1.0s).
#
# Processing: f0115_0_throatclearing.wav
# Trimmed Core (3.317s) -> MAX DURATION (1.0s).
#
# Processing: f1443_0_laughter.wav
# Trimmed Core (2.240s) -> MAX DURATION (1.0s).
#
# Processing: m1679_0_sneeze.wav
# Kept natural duration: 0.864s (less than 1.0s max).
#
# Processing: f1456_0_laughter.wav
# Trimmed Core (7.648s) -> MAX DURATION (1.0s).
#
# Processing: m0379_0_sneeze.wav
# Trimmed Core (1.792s) -> MAX DURATION (1.0s).
#
# Processing: f2359_0_cough.wav
# Trimmed Core (1.632s) -> MAX DURATION (1.0s).
#
# Processing: m2809_0_laughter.wav
# Trimmed Core (2.816s) -> MAX DURATION (1.0s).
#
# Processing: m1609_0_laughter.wav
# Trimmed Core (8.032s) -> MAX DURATION (1.0s).
#
# Processing: f2942_0_sigh.wav
# Trimmed Core (2.475s) -> MAX DURATION (1.0s).
#
# Processing: m0386_0_sneeze.wav
# Kept natural duration: 0.704s (less than 1.0s max).
#
# Processing: m0886_0_sigh.wav
# Trimmed Core (4.267s) -> MAX DURATION (1.0s).
#
# Processing: m1426_0_throatclearing.wav
# Trimmed Core (6.873s) -> MAX DURATION (1.0s).
#
# Processing: f1366_0_sneeze.wav
# Trimmed Core (1.632s) -> MAX DURATION (1.0s).
#
# Processing: f1415_0_sigh.wav
# Trimmed Core (5.291s) -> MAX DURATION (1.0s).
#
# Processing: m2301_0_sniff.wav
# Trimmed Core (2.176s) -> MAX DURATION (1.0s).
#
# Processing: f3184_0_cough.wav
# Trimmed Core (2.400s) -> MAX DURATION (1.0s).
#
# Processing: f1741_0_sniff.wav
# Trimmed Core (4.064s) -> MAX DURATION (1.0s).
#
# Processing: f0153_0_sniff.wav
# Trimmed Core (3.437s) -> MAX DURATION (1.0s).
#
# Processing: f2796_0_cough.wav
# Trimmed Core (3.328s) -> MAX DURATION (1.0s).
#
# Processing: f3182_0_sneeze.wav
# Kept natural duration: 0.576s (less than 1.0s max).
#
# Processing: m0094_0_cough.wav
# Trimmed Core (3.168s) -> MAX DURATION (1.0s).
#
# Processing: m2651_0_sniff.wav
# Trimmed Core (2.869s) -> MAX DURATION (1.0s).
#
# Processing: f2482_0_sneeze.wav
# Trimmed Core (1.920s) -> MAX DURATION (1.0s).
#
# Processing: m1469_0_sigh.wav
# Trimmed Core (3.531s) -> MAX DURATION (1.0s).
#
# Processing: f0471_0_cough.wav
# Trimmed Core (3.872s) -> MAX DURATION (1.0s).
#
# Processing: m3148_0_laughter.wav
# Trimmed Core (1.504s) -> MAX DURATION (1.0s).
#
# Processing: m3043_0_sniff.wav
# Trimmed Core (3.605s) -> MAX DURATION (1.0s).
#
# Processing: m2137_0_sneeze.wav
# Trimmed Core (1.216s) -> MAX DURATION (1.0s).
#
# Processing: f1668_0_sigh.wav
# Trimmed Core (2.528s) -> MAX DURATION (1.0s).
#
# Processing: m1976_0_cough.wav
# Trimmed Core (1.120s) -> MAX DURATION (1.0s).
#
# Processing: f2814_0_sniff.wav
# Trimmed Core (3.808s) -> MAX DURATION (1.0s).
#
# Processing: f2866_0_cough.wav
# Trimmed Core (2.592s) -> MAX DURATION (1.0s).
#
# Processing: f1902_0_cough.wav
# Trimmed Core (3.413s) -> MAX DURATION (1.0s).
#
# Processing: f0468_0_throatclearing.wav
# Trimmed Core (3.243s) -> MAX DURATION (1.0s).
#
# Processing: f1970_0_sniff.wav
#  WARNING: Audio file vs_release_16k/audio_16k/f1970_0_sniff.wav was too quiet (-96). Skipping...
#
# Processing: m0582_4_throatclearing.wav
# Trimmed Core (1.728s) -> MAX DURATION (1.0s).
#
# Processing: m0213_0_laughter.wav
# Trimmed Core (1.408s) -> MAX DURATION (1.0s).
#
# Processing: m2860_0_sniff.wav
# Trimmed Core (3.104s) -> MAX DURATION (1.0s).
#
# Processing: m2812_0_cough.wav
# Trimmed Core (1.376s) -> MAX DURATION (1.0s).
#
# Processing: f1608_0_sneeze.wav
# Trimmed Core (5.920s) -> MAX DURATION (1.0s).
#
# Processing: m1747_0_cough.wav
# Trimmed Core (2.176s) -> MAX DURATION (1.0s).
#
# Processing: m0659_0_throatclearing.wav
# Trimmed Core (3.808s) -> MAX DURATION (1.0s).
#
# Processing: f2375_0_sniff.wav
# Trimmed Core (2.389s) -> MAX DURATION (1.0s).
#
# Processing: m1342_0_sneeze.wav
# Trimmed Core (1.216s) -> MAX DURATION (1.0s).
#
# Processing: m1735_0_sniff.wav
# Trimmed Core (4.981s) -> MAX DURATION (1.0s).
#
# Processing: m2790_0_sniff.wav
# Trimmed Core (2.304s) -> MAX DURATION (1.0s).
#
# Processing: m0155_0_cough.wav
# Trimmed Core (2.976s) -> MAX DURATION (1.0s).
#
# Processing: m0879_0_sigh.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: m0127_0_sniff.wav
# Trimmed Core (3.584s) -> MAX DURATION (1.0s).
#
# Processing: f2625_0_sniff.wav
# Trimmed Core (8.256s) -> MAX DURATION (1.0s).
#
# Processing: m2732_0_sigh.wav
# Trimmed Core (5.205s) -> MAX DURATION (1.0s).
#
# Processing: f1680_0_sniff.wav
# Trimmed Core (4.352s) -> MAX DURATION (1.0s).
#
# Processing: f1777_0_throatclearing.wav
# Trimmed Core (1.952s) -> MAX DURATION (1.0s).
#
# Processing: m2982_0_throatclearing.wav
# Trimmed Core (2.752s) -> MAX DURATION (1.0s).
#
# Processing: m0033_0_throatclearing.wav
# Trimmed Core (3.669s) -> MAX DURATION (1.0s).
#
# Processing: m1818_0_sigh.wav
# Trimmed Core (4.052s) -> MAX DURATION (1.0s).
#
# Processing: m1496_0_sigh.wav
# Trimmed Core (3.584s) -> MAX DURATION (1.0s).
#
# Processing: m1731_0_throatclearing.wav
# Trimmed Core (5.685s) -> MAX DURATION (1.0s).
#
# Processing: m1928_0_cough.wav
# Trimmed Core (2.219s) -> MAX DURATION (1.0s).
#
# Processing: m2807_0_sneeze.wav
# Trimmed Core (3.168s) -> MAX DURATION (1.0s).
#
# Processing: f2298_0_cough.wav
# WARNING: Audio file vs_release_16k/audio_16k/f2298_0_cough.wav too short (0.00s). Skipping...
#
# Processing: f1388_0_sigh.wav
# Trimmed Core (2.144s) -> MAX DURATION (1.0s).
#
# Processing: f0194_0_sigh.wav
# Trimmed Core (3.648s) -> MAX DURATION (1.0s).
#
# Processing: m2547_0_laughter.wav
# Trimmed Core (3.392s) -> MAX DURATION (1.0s).
#
# Processing: m2971_0_throatclearing.wav
# Trimmed Core (3.296s) -> MAX DURATION (1.0s).
#
# Processing: m2552_0_laughter.wav
# Trimmed Core (2.112s) -> MAX DURATION (1.0s).
#
# Processing: m0395_0_sigh.wav
# Trimmed Core (3.659s) -> MAX DURATION (1.0s).
#
# Processing: m1546_0_throatclearing.wav
# Trimmed Core (1.824s) -> MAX DURATION (1.0s).
#
# Processing: m2050_0_sigh.wav
# Trimmed Core (2.304s) -> MAX DURATION (1.0s).
#
# Processing: f0204_0_laughter.wav
# Trimmed Core (2.272s) -> MAX DURATION (1.0s).
#
# Processing: f2251_0_sigh.wav
# Trimmed Core (1.056s) -> MAX DURATION (1.0s).
#
# Processing: f0211_0_laughter.wav
# Trimmed Core (4.458s) -> MAX DURATION (1.0s).
#
# Processing: f2937_0_throatclearing.wav
# Trimmed Core (1.152s) -> MAX DURATION (1.0s).
#
# Processing: f1500_0_throatclearing.wav
# Trimmed Core (6.485s) -> MAX DURATION (1.0s).
#
# Processing: f0086_0_throatclearing.wav
# Trimmed Core (1.152s) -> MAX DURATION (1.0s).
#
# Processing: m0612_0_laughter.wav
# Trimmed Core (7.456s) -> MAX DURATION (1.0s).
#
# Processing: m1466_0_sneeze.wav
# Trimmed Core (2.592s) -> MAX DURATION (1.0s).
#
# Processing: m2089_0_sniff.wav
#  WARNING: Audio file vs_release_16k/audio_16k/m2089_0_sniff.wav was too quiet (-66). Skipping...
#
# Processing: m1892_0_sneeze.wav
# Kept natural duration: 0.608s (less than 1.0s max).
#
# Processing: f0827_0_sneeze.wav
# Trimmed Core (2.144s) -> MAX DURATION (1.0s).
#
# Processing: m1433_0_sneeze.wav
# Kept natural duration: 0.544s (less than 1.0s max).
#
# Processing: m2067_0_sigh.wav
# Kept natural duration: 0.896s (less than 1.0s max).
#
# Processing: f1199_0_sniff.wav
# Trimmed Core (2.955s) -> MAX DURATION (1.0s).
#
# Processing: m0133_0_sneeze.wav
# Trimmed Core (4.192s) -> MAX DURATION (1.0s).
#
# Processing: f0872_0_sneeze.wav
# Trimmed Core (4.864s) -> MAX DURATION (1.0s).
#
# Processing: f1186_0_sneeze.wav
# Trimmed Core (2.187s) -> MAX DURATION (1.0s).
#
# Processing: m1838_0_sneeze.wav
# Trimmed Core (1.408s) -> MAX DURATION (1.0s).
#
# Processing: f0809_0_cough.wav
# Trimmed Core (1.920s) -> MAX DURATION (1.0s).
#
# Processing: m1499_0_sneeze.wav
# Trimmed Core (2.251s) -> MAX DURATION (1.0s).
#
# Processing: f0458_0_laughter.wav
# Trimmed Core (4.512s) -> MAX DURATION (1.0s).
#
# Processing: m2578_0_sigh.wav
# Trimmed Core (4.181s) -> MAX DURATION (1.0s).
#
# Processing: f2779_0_sigh.wav
# Trimmed Core (1.888s) -> MAX DURATION (1.0s).
#
# Processing: m2116_0_sniff.wav
# Trimmed Core (2.528s) -> MAX DURATION (1.0s).
#
# Processing: f2319_0_laughter.wav
# Trimmed Core (5.397s) -> MAX DURATION (1.0s).
#
# Processing: m2328_0_sneeze.wav
# Trimmed Core (3.499s) -> MAX DURATION (1.0s).
#
# Processing: f1197_0_throatclearing.wav
# Trimmed Core (3.776s) -> MAX DURATION (1.0s).
#
# Processing: f0336_0_cough.wav
# Trimmed Core (2.368s) -> MAX DURATION (1.0s).
#
# Processing: m1355_0_throatclearing.wav
# Kept natural duration: 0.928s (less than 1.0s max).
#
# Processing: m2434_0_cough.wav
# Trimmed Core (6.144s) -> MAX DURATION (1.0s).
#
# Processing: f1074_0_cough.wav
# Trimmed Core (6.976s) -> MAX DURATION (1.0s).
#
# Processing: m0283_0_cough.wav
# Trimmed Core (2.528s) -> MAX DURATION (1.0s).
#
# Processing: m3226_0_cough.wav
# Trimmed Core (2.112s) -> MAX DURATION (1.0s).
#
# Processing: f0614_0_sniff.wav
# Trimmed Core (3.270s) -> MAX DURATION (1.0s).
#
# Processing: m3254_0_sniff.wav
# Trimmed Core (1.920s) -> MAX DURATION (1.0s).
#
# Processing: f1313_0_throatclearing.wav
# Trimmed Core (1.536s) -> MAX DURATION (1.0s).
#
# Processing: m2578_1_sigh.wav
# Trimmed Core (5.312s) -> MAX DURATION (1.0s).
#
# Processing: m0620_0_throatclearing.wav
# Trimmed Core (2.022s) -> MAX DURATION (1.0s).
#
# Processing: f0610_0_laughter.wav
# Trimmed Core (7.552s) -> MAX DURATION (1.0s).
#
# Processing: m2382_0_sneeze.wav
# Trimmed Core (3.136s) -> MAX DURATION (1.0s).
#
# Processing: f0605_0_laughter.wav
# Trimmed Core (8.448s) -> MAX DURATION (1.0s).
#
# Processing: m3006_0_sigh.wav
# Trimmed Core (1.888s) -> MAX DURATION (1.0s).
#
# Processing: f2662_0_sneeze.wav
# Trimmed Core (1.120s) -> MAX DURATION (1.0s).
#
# Processing: m0823_0_cough.wav
# Trimmed Core (2.112s) -> MAX DURATION (1.0s).
#
# Processing: m2153_0_laughter.wav
# Trimmed Core (4.779s) -> MAX DURATION (1.0s).
#
# Processing: m2146_0_laughter.wav
# Trimmed Core (3.232s) -> MAX DURATION (1.0s).
#
# Processing: m2144_0_sigh.wav
# Trimmed Core (8.608s) -> MAX DURATION (1.0s).
#
# Processing: m3358_0_sigh.wav
# Trimmed Core (1.216s) -> MAX DURATION (1.0s).
#
# Processing: f2695_0_laughter.wav
# Trimmed Core (3.456s) -> MAX DURATION (1.0s).
#
# Processing: f0991_0_throatclearing.wav
# Trimmed Core (2.693s) -> MAX DURATION (1.0s).
#
# Processing: f3159_0_sigh.wav
# Trimmed Core (2.144s) -> MAX DURATION (1.0s).
#
# Processing: f2680_0_laughter.wav
# Trimmed Core (2.508s) -> MAX DURATION (1.0s).
#
# Processing: f0080_0_sigh.wav
# Trimmed Core (2.048s) -> MAX DURATION (1.0s).
#
# Processing: f1378_0_laughter.wav
# Trimmed Core (2.304s) -> MAX DURATION (1.0s).
#
# Processing: f0919_0_sniff.wav
# Trimmed Core (1.632s) -> MAX DURATION (1.0s).
#
# Processing: f0962_0_throatclearing.wav
# Trimmed Core (1.804s) -> MAX DURATION (1.0s).
#
# Processing: f1089_0_cough.wav
# Trimmed Core (6.272s) -> MAX DURATION (1.0s).
#
# Processing: m1127_0_laughter.wav
# Trimmed Core (4.064s) -> MAX DURATION (1.0s).
#
# Processing: m1544_0_sneeze.wav
# Trimmed Core (1.984s) -> MAX DURATION (1.0s).
#
# Processing: m0044_0_sneeze.wav
# Trimmed Core (4.286s) -> MAX DURATION (1.0s).
#
# Processing: f2257_0_throatclearing.wav
# Kept natural duration: 0.896s (less than 1.0s max).
#
# Processing: f0950_0_sneeze.wav
# Trimmed Core (4.480s) -> MAX DURATION (1.0s).
#
# Processing: m0011_0_sneeze.wav
# Trimmed Core (1.408s) -> MAX DURATION (1.0s).
#
# Processing: m2626_0_sigh.wav
# Trimmed Core (5.480s) -> MAX DURATION (1.0s).
#
# Processing: m0941_0_cough.wav
# Trimmed Core (2.048s) -> MAX DURATION (1.0s).
#
# Processing: f3215_0_sneeze.wav
# Kept natural duration: 0.928s (less than 1.0s max).
#
# Processing: f1970_0_sigh.wav
#  WARNING: Audio file vs_release_16k/audio_16k/f1970_0_sigh.wav was too quiet (-96). Skipping...
#
# Processing: f3240_0_sneeze.wav
# Trimmed Core (6.368s) -> MAX DURATION (1.0s).
#
# Processing: m2339_0_sigh.wav
# Trimmed Core (8.395s) -> MAX DURATION (1.0s).
#
# Processing: m2682_0_laughter.wav
# Trimmed Core (2.080s) -> MAX DURATION (1.0s).
#
# Processing: f1116_0_cough.wav
# Trimmed Core (6.144s) -> MAX DURATION (1.0s).
#
# Processing: f0776_0_sniff.wav
# Trimmed Core (3.344s) -> MAX DURATION (1.0s).
#
# Processing: m0873_0_laughter.wav
# Trimmed Core (5.888s) -> MAX DURATION (1.0s).
#
# Processing: m1581_0_sniff.wav
# Trimmed Core (4.779s) -> MAX DURATION (1.0s).
#
# Processing: m2488_0_throatclearing.wav
# Trimmed Core (1.056s) -> MAX DURATION (1.0s).
#
# Processing: f3324_0_sigh.wav
# Trimmed Core (1.920s) -> MAX DURATION (1.0s).
#
# Processing: f1434_0_sniff.wav
# Trimmed Core (2.560s) -> MAX DURATION (1.0s).
#
# Processing: m2006_0_cough.wav
# Trimmed Core (7.424s) -> MAX DURATION (1.0s).
#
# Processing: m2074_0_sniff.wav
# Trimmed Core (1.888s) -> MAX DURATION (1.0s).
#
# Processing: f3283_0_sniff.wav
#  WARNING: Audio file vs_release_16k/audio_16k/f3283_0_sniff.wav was too quiet (-96). Skipping...
#
# Processing: m2301_1_throatclearing.wav
# Trimmed Core (1.504s) -> MAX DURATION (1.0s).
#
# Processing: f0226_0_sniff.wav
# Trimmed Core (2.219s) -> MAX DURATION (1.0s).
#
# Processing: f0254_0_cough.wav
# Trimmed Core (4.864s) -> MAX DURATION (1.0s).
#
# Processing: m2402_0_throatclearing.wav
# Trimmed Core (2.048s) -> MAX DURATION (1.0s).
#
# Processing: f2747_0_sniff.wav
# Trimmed Core (2.475s) -> MAX DURATION (1.0s).
#
# Processing: f0182_0_cough.wav
# Kept natural duration: 0.960s (less than 1.0s max).
#
# Processing: f3346_0_throatclearing.wav
# Trimmed Core (2.848s) -> MAX DURATION (1.0s).
#
# Processing: m1835_0_throatclearing.wav
# Trimmed Core (1.056s) -> MAX DURATION (1.0s).
#
# Processing: m0760_0_sneeze.wav
# Kept natural duration: 0.864s (less than 1.0s max).
#
# Processing: f1790_0_cough.wav
# Trimmed Core (1.984s) -> MAX DURATION (1.0s).
#
# Processing: f3155_0_sniff.wav
# Trimmed Core (2.777s) -> MAX DURATION (1.0s).
#
# Processing: f1779_0_laughter.wav
# Trimmed Core (2.784s) -> MAX DURATION (1.0s).
#
# Processing: m0515_0_sniff.wav
# Trimmed Core (3.648s) -> MAX DURATION (1.0s).
#
# Processing: f3127_0_cough.wav
# Trimmed Core (5.056s) -> MAX DURATION (1.0s).
#
# Processing: m1625_0_cough.wav
# Trimmed Core (3.424s) -> MAX DURATION (1.0s).
#
# Processing: f0280_0_sneeze.wav
# Trimmed Core (1.952s) -> MAX DURATION (1.0s).
#
# Processing: m3300_0_throatclearing.wav
# Trimmed Core (2.080s) -> MAX DURATION (1.0s).
#
# Processing: m3092_0_cough.wav
# Trimmed Core (2.475s) -> MAX DURATION (1.0s).
#
# Processing: f2265_0_cough.wav
# Trimmed Core (4.448s) -> MAX DURATION (1.0s).
#
# Processing: m0045_0_sniff.wav
# Trimmed Core (2.048s) -> MAX DURATION (1.0s).
#
# Processing: m1235_0_sneeze.wav
# Trimmed Core (1.696s) -> MAX DURATION (1.0s).
#
# Processing: m2611_0_sigh.wav
# Trimmed Core (1.184s) -> MAX DURATION (1.0s).
#
# Processing: m3177_0_throatclearing.wav
# Trimmed Core (3.424s) -> MAX DURATION (1.0s).
#
# Processing: f2633_0_throatclearing.wav
# Trimmed Core (1.088s) -> MAX DURATION (1.0s).
#
# Processing: f3265_0_laughter.wav
# Trimmed Core (2.741s) -> MAX DURATION (1.0s).
#
# Processing: m2970_0_cough.wav
# Trimmed Core (6.016s) -> MAX DURATION (1.0s).
#
# Processing: f1947_0_sigh.wav
# Trimmed Core (1.824s) -> MAX DURATION (1.0s).
#
# Processing: f0788_0_laughter.wav
# Trimmed Core (3.872s) -> MAX DURATION (1.0s).
#
# Processing: f3131_0_throatclearing.wav
# Kept natural duration: 0.704s (less than 1.0s max).
#
# Processing: m1533_0_laughter.wav
# Trimmed Core (4.907s) -> MAX DURATION (1.0s).
#
# Processing: m1526_0_laughter.wav
# Trimmed Core (1.792s) -> MAX DURATION (1.0s).
#
# Processing: m3272_0_laughter.wav
# Trimmed Core (2.048s) -> MAX DURATION (1.0s).
#
# Processing: m3267_0_laughter.wav
# Trimmed Core (6.223s) -> MAX DURATION (1.0s).
#
# Processing: f2059_0_throatclearing.wav
# Trimmed Core (2.720s) -> MAX DURATION (1.0s).
#
# Processing: f0926_0_sigh.wav
# Trimmed Core (2.101s) -> MAX DURATION (1.0s).
#
# Processing: f2738_1_sneeze.wav
# Trimmed Core (5.728s) -> MAX DURATION (1.0s).
#
# Processing: f2388_0_sniff.wav
# Trimmed Core (2.080s) -> MAX DURATION (1.0s).
#
# Processing: f1947_1_sigh.wav
# Trimmed Core (3.125s) -> MAX DURATION (1.0s).
#
# Processing: m2584_0_sneeze.wav
# Kept natural duration: 0.704s (less than 1.0s max).
#
# Processing: m1838_0_sniff.wav
# Trimmed Core (3.136s) -> MAX DURATION (1.0s).
#
# Processing: m2970_0_sneeze.wav
# Trimmed Core (3.168s) -> MAX DURATION (1.0s).
#
# Processing: f2031_0_sneeze.wav
# Trimmed Core (1.696s) -> MAX DURATION (1.0s).
#
# Processing: f3038_0_laughter.wav
# Trimmed Core (1.696s) -> MAX DURATION (1.0s).
#
# Processing: m2283_0_laughter.wav
# Trimmed Core (1.696s) -> MAX DURATION (1.0s).
#
# Processing: m2296_0_laughter.wav
# Trimmed Core (3.200s) -> MAX DURATION (1.0s).
#
# Processing: m2925_0_sneeze.wav
# Trimmed Core (1.696s) -> MAX DURATION (1.0s).
#
# Processing: m1819_0_laughter.wav
# Trimmed Core (2.645s) -> MAX DURATION (1.0s).
#
# Processing: f2305_0_sniff.wav
# Trimmed Core (2.560s) -> MAX DURATION (1.0s).
#
# Processing: m0645_0_sneeze.wav
# Trimmed Core (2.918s) -> MAX DURATION (1.0s).
#
# Processing: m1737_0_cough.wav
# Trimmed Core (9.557s) -> MAX DURATION (1.0s).
#
# Processing: f2446_0_laughter.wav
# Trimmed Core (3.157s) -> MAX DURATION (1.0s).
#
# Processing: f2712_0_throatclearing.wav
# Kept natural duration: 0.990s (less than 1.0s max).
#
# Processing: m3180_0_cough.wav
# Trimmed Core (6.130s) -> MAX DURATION (1.0s).
#
# Processing: m1345_0_sneeze.wav
# Trimmed Core (2.080s) -> MAX DURATION (1.0s).
#
# Processing: m3056_0_throatclearing.wav
# Trimmed Core (1.248s) -> MAX DURATION (1.0s).
#
# Processing: f2377_0_cough.wav
# Trimmed Core (5.216s) -> MAX DURATION (1.0s).
#
# Processing: f1682_0_cough.wav
# Trimmed Core (4.437s) -> MAX DURATION (1.0s).
#
# Processing: m0407_0_sniff.wav
# Trimmed Core (2.219s) -> MAX DURATION (1.0s).
#
# Processing: f3035_0_cough.wav
# Trimmed Core (2.400s) -> MAX DURATION (1.0s).
#
# Processing: f2233_0_sigh.wav
# Trimmed Core (6.443s) -> MAX DURATION (1.0s).
#
# Processing: m1215_0_sniff.wav
# Trimmed Core (2.325s) -> MAX DURATION (1.0s).
#
# Processing: m2754_0_throatclearing.wav
# Trimmed Core (2.592s) -> MAX DURATION (1.0s).
#
# Processing: f3010_0_throatclearing.wav
# Trimmed Core (4.032s) -> MAX DURATION (1.0s).
#
# Processing: m1914_0_throatclearing.wav
# Trimmed Core (1.600s) -> MAX DURATION (1.0s).
#
# Processing: m2523_0_throatclearing.wav
# Trimmed Core (1.536s) -> MAX DURATION (1.0s).
#
# Processing: m2810_0_sniff.wav
# Trimmed Core (2.848s) -> MAX DURATION (1.0s).
#
# Processing: f0593_2_sigh.wav
# Trimmed Core (1.056s) -> MAX DURATION (1.0s).
#
# Processing: m3221_0_throatclearing.wav
# Trimmed Core (2.080s) -> MAX DURATION (1.0s).
#
# Processing: f1952_0_throatclearing.wav
#  WARNING: Audio file vs_release_16k/audio_16k/f1952_0_throatclearing.wav was too quiet (-61). Skipping...
#
# Processing: o0005_0_laughter.wav
# Trimmed Core (2.208s) -> MAX DURATION (1.0s).
#
# Processing: m2619_0_laughter.wav
# Kept natural duration: 0.928s (less than 1.0s max).
#
# Processing: m0495_0_sigh.wav
# Trimmed Core (2.304s) -> MAX DURATION (1.0s).
#
# Processing: f1488_0_sigh.wav
# Trimmed Core (1.696s) -> MAX DURATION (1.0s).
#
# Processing: f2551_0_sigh.wav
#  WARNING: Audio file vs_release_16k/audio_16k/f2551_0_sigh.wav was too quiet (-82). Skipping...
#
# Processing: m2444_0_laughter.wav
# Trimmed Core (1.696s) -> MAX DURATION (1.0s).
#
# Processing: f2114_0_sneeze.wav
# Trimmed Core (2.240s) -> MAX DURATION (1.0s).
#
# Processing: f1197_0_sigh.wav
# Trimmed Core (3.264s) -> MAX DURATION (1.0s).
#
# Processing: f2848_0_cough.wav
# Trimmed Core (4.160s) -> MAX DURATION (1.0s).
#
# Processing: f0307_0_laughter.wav
# Trimmed Core (2.112s) -> MAX DURATION (1.0s).
#
# Processing: m2800_0_sneeze.wav
# Kept natural duration: 0.800s (less than 1.0s max).
#
# Processing: m1958_0_cough.wav
# Trimmed Core (2.048s) -> MAX DURATION (1.0s).
#
# Processing: m2330_0_throatclearing.wav
# Trimmed Core (3.360s) -> MAX DURATION (1.0s).
#
# Processing: f0843_0_throatclearing.wav
# Trimmed Core (3.243s) -> MAX DURATION (1.0s).
#
# Processing: m0704_0_laughter.wav
# Trimmed Core (1.440s) -> MAX DURATION (1.0s).
#
# Processing: f3265_0_sigh.wav
# Trimmed Core (3.584s) -> MAX DURATION (1.0s).
#
# Processing: m0805_0_throatclearing.wav
# Trimmed Core (2.240s) -> MAX DURATION (1.0s).
#
# Processing: f2376_0_throatclearing.wav
# Trimmed Core (4.032s) -> MAX DURATION (1.0s).
#
# Processing: m2278_0_sigh.wav
# Trimmed Core (3.024s) -> MAX DURATION (1.0s).
#
# Processing: f0820_0_sneeze.wav
# Trimmed Core (4.608s) -> MAX DURATION (1.0s).
#
# Processing: f1831_0_sigh.wav
# Trimmed Core (1.707s) -> MAX DURATION (1.0s).
#
# Processing: m1461_0_sneeze.wav
# Trimmed Core (1.600s) -> MAX DURATION (1.0s).
#
# Processing: m0161_0_sneeze.wav
# Trimmed Core (1.088s) -> MAX DURATION (1.0s).
#
# Processing: f2101_0_throatclearing.wav
# Trimmed Core (2.560s) -> MAX DURATION (1.0s).
#
# Processing: m1895_0_sneeze.wav
# Trimmed Core (2.688s) -> MAX DURATION (1.0s).
#
# Processing: f0789_0_cough.wav
# Trimmed Core (1.536s) -> MAX DURATION (1.0s).
#
# Processing: m2147_0_throatclearing.wav
# Trimmed Core (3.136s) -> MAX DURATION (1.0s).
#
# Processing: f2385_0_throatclearing.wav
# Trimmed Core (3.403s) -> MAX DURATION (1.0s).
#
# Processing: m2767_0_sigh.wav
#  WARNING: Audio file vs_release_16k/audio_16k/m2767_0_sigh.wav was too quiet (-91). Skipping...
#
# Processing: f0994_0_sniff.wav
# Trimmed Core (1.664s) -> MAX DURATION (1.0s).
#
# Processing: f2630_0_sneeze.wav
# Trimmed Core (4.864s) -> MAX DURATION (1.0s).
#
# Processing: f0850_0_sigh.wav
# Trimmed Core (3.947s) -> MAX DURATION (1.0s).
#
# Processing: m0559_0_laughter.wav
# Trimmed Core (3.808s) -> MAX DURATION (1.0s).
#
# Processing: f3069_0_throatclearing.wav
# Kept natural duration: 0.992s (less than 1.0s max).
#
# Processing: m0853_0_cough.wav
# Trimmed Core (2.912s) -> MAX DURATION (1.0s).
#
# Processing: f2665_0_sneeze.wav
# Trimmed Core (4.437s) -> MAX DURATION (1.0s).
#
# Processing: m2994_0_sigh.wav
# Trimmed Core (3.776s) -> MAX DURATION (1.0s).
#
# Processing: f0706_0_laughter.wav
# Trimmed Core (2.368s) -> MAX DURATION (1.0s).
#
# Processing: f0334_0_sniff.wav
# Trimmed Core (3.616s) -> MAX DURATION (1.0s).
#
# Processing: f2798_0_throatclearing.wav
# Trimmed Core (1.152s) -> MAX DURATION (1.0s).
#
# Processing: m2166_0_sniff.wav
# Trimmed Core (2.048s) -> MAX DURATION (1.0s).
#
# Processing: m2045_0_laughter.wav
# Trimmed Core (2.752s) -> MAX DURATION (1.0s).
#
# Processing: f0664_0_sniff.wav
# Trimmed Core (4.608s) -> MAX DURATION (1.0s).
#
# Processing: m3258_0_throatclearing.wav
# Trimmed Core (2.219s) -> MAX DURATION (1.0s).
#
# Processing: m1493_0_sniff.wav
# Trimmed Core (3.317s) -> MAX DURATION (1.0s).
#
# Processing: m3224_0_sniff.wav
# Trimmed Core (4.693s) -> MAX DURATION (1.0s).
#
# Processing: f0616_0_cough.wav
# Trimmed Core (4.160s) -> MAX DURATION (1.0s).
#
# Processing: m2050_0_laughter.wav
# Trimmed Core (1.216s) -> MAX DURATION (1.0s).
#
# Processing: m2444_0_cough.wav
# Trimmed Core (2.464s) -> MAX DURATION (1.0s).
#
# Processing: f1004_0_cough.wav
# Trimmed Core (2.176s) -> MAX DURATION (1.0s).
#
# Processing: f2783_0_laughter.wav
# Trimmed Core (6.560s) -> MAX DURATION (1.0s).
#
# Processing: m1543_0_sneeze.wav
# Kept natural duration: 0.768s (less than 1.0s max).
#
# Processing: f3346_0_sigh.wav
#  WARNING: Audio file vs_release_16k/audio_16k/f3346_0_sigh.wav was too quiet (-53). Skipping...
#
# Processing: f2796_0_laughter.wav
# Trimmed Core (2.699s) -> MAX DURATION (1.0s).
#
# Processing: m2829_0_throatclearing.wav
# Trimmed Core (6.272s) -> MAX DURATION (1.0s).
#
# Processing: m0198_0_throatclearing.wav
# Trimmed Core (2.432s) -> MAX DURATION (1.0s).
#
# Processing: m0016_0_sneeze.wav
# Trimmed Core (4.000s) -> MAX DURATION (1.0s).
#
# Processing: f1083_0_sigh.wav
# Trimmed Core (3.994s) -> MAX DURATION (1.0s).
#
# Processing: m1024_0_laughter.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: m1669_0_throatclearing.wav
# Trimmed Core (1.760s) -> MAX DURATION (1.0s).
#
# Processing: f0969_0_sniff.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: m1948_0_sneeze.wav
# ...
#
# Processing: m0609_0_cough.wav
# Trimmed Core (3.669s) -> MAX DURATION (1.0s).
#
# Processing: m1768_0_sneeze.wav
# Trimmed Core (6.016s) -> MAX DURATION (1.0s).
#
# Processing: m1069_0_sniff.wav
# Trimmed Core (4.160s) -> MAX DURATION (1.0s).
#
# Processing: m0049_0_throatclearing.wav
# Trimmed Core (2.043s) -> MAX DURATION (1.0s).
#
# Processing: m0268_0_sneeze.wav
# Kept natural duration: 0.960s (less than 1.0s max).
#
# Processing: f1288_0_sneeze.wav
# Trimmed Core (1.248s) -> MAX DURATION (1.0s).
#
# Processing: m2437_0_sigh.wav
# Trimmed Core (6.229s) -> MAX DURATION (1.0s).
#
# Processing: f0788_0_sneeze.wav
# Trimmed Core (4.064s) -> MAX DURATION (1.0s).
#
# Processing: m0359_0_cough.wav
# Trimmed Core (8.107s) -> MAX DURATION (1.0s).
#
# Processing: f2179_0_sniff.wav
# Trimmed Core (3.808s) -> MAX DURATION (1.0s).
#
# Processing: f0278_0_throatclearing.wav
# Trimmed Core (8.021s) -> MAX DURATION (1.0s).
#
# Processing: m0589_2_sneeze.wav
# Trimmed Core (4.480s) -> MAX DURATION (1.0s).
#
# Processing: f0777_0_sneeze.wav
# Trimmed Core (1.024s) -> MAX DURATION (1.0s).
#
# Processing: f0415_0_laughter.wav
# Trimmed Core (3.008s) -> MAX DURATION (1.0s).
#
# Processing: m2128_0_sigh.wav
# Trimmed Core (5.035s) -> MAX DURATION (1.0s).
#
# Processing: m0561_1_sneeze.wav
# Trimmed Core (1.088s) -> MAX DURATION (1.0s).
#
# Processing: m1797_0_sneeze.wav
# Trimmed Core (3.392s) -> MAX DURATION (1.0s).
#
# Processing: m2343_0_laughter.wav
# Trimmed Core (4.011s) -> MAX DURATION (1.0s).
#
# Processing: m0297_0_sneeze.wav
# Trimmed Core (1.120s) -> MAX DURATION (1.0s).
#
# Processing: m3303_0_sniff.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: f2268_0_sigh.wav
# Trimmed Core (2.603s) -> MAX DURATION (1.0s).
#
# Processing: f2186_0_cough.wav
# Trimmed Core (3.133s) -> MAX DURATION (1.0s).
#
# Processing: m2103_0_sneeze.wav
# Trimmed Core (2.464s) -> MAX DURATION (1.0s).
#
# Processing: f0743_0_sniff.wav
# Trimmed Core (6.229s) -> MAX DURATION (1.0s).
#
# Processing: m2511_0_sniff.wav
# Trimmed Core (3.078s) -> MAX DURATION (1.0s).
#
# Processing: m0702_0_throatclearing.wav
# Kept natural duration: 0.992s (less than 1.0s max).
#
# Processing: m3275_0_sigh.wav
# Trimmed Core (4.096s) -> MAX DURATION (1.0s).
#
# Processing: m2069_0_sigh.wav
#  WARNING: Audio file vs_release_16k/audio_16k/m2069_0_sigh.wav was too quiet (-96). Skipping...
#
# Processing: m1096_0_cough.wav
# Trimmed Core (9.120s) -> MAX DURATION (1.0s).
#
# Processing: m2041_0_sniff.wav
# Trimmed Core (2.944s) -> MAX DURATION (1.0s).
#
# Processing: m0586_0_throatclearing.wav
#  WARNING: Audio file vs_release_16k/audio_16k/m0586_0_throatclearing.wav was too quiet (-96). Skipping...
#
# Processing: f1473_0_cough.wav
# Trimmed Core (2.976s) -> MAX DURATION (1.0s).
#
# Processing: f1401_0_sniff.wav
# Trimmed Core (3.712s) -> MAX DURATION (1.0s).
#
# Processing: m2033_0_cough.wav
# Kept natural duration: 0.896s (less than 1.0s max).
#
# Processing: m1277_0_throatclearing.wav
# Trimmed Core (1.824s) -> MAX DURATION (1.0s).
#
# Processing: m1221_0_laughter.wav
# Trimmed Core (4.779s) -> MAX DURATION (1.0s).
#
# Processing: f2777_0_sigh.wav
# Trimmed Core (7.552s) -> MAX DURATION (1.0s).
#
# Processing: m0906_0_sniff.wav
# Trimmed Core (2.901s) -> MAX DURATION (1.0s).
#
# Processing: m0575_0_throatclearing.wav
# Trimmed Core (4.896s) -> MAX DURATION (1.0s).
#
# Processing: m1821_0_sigh.wav
# Trimmed Core (1.760s) -> MAX DURATION (1.0s).
#
# Processing: f3149_0_sneeze.wav
# Trimmed Core (4.608s) -> MAX DURATION (1.0s).
#
# Processing: m0078_1_throatclearing.wav
# Trimmed Core (2.624s) -> MAX DURATION (1.0s).
#
# Processing: f2449_0_sneeze.wav
# Trimmed Core (2.624s) -> MAX DURATION (1.0s).
#
# Processing: f2019_0_cough.wav
# Trimmed Core (2.016s) -> MAX DURATION (1.0s).
#
# Processing: f2984_0_sigh.wav
# Trimmed Core (2.879s) -> MAX DURATION (1.0s).
#
# Processing: m0239_0_sniff.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: f1236_0_laughter.wav
# Trimmed Core (3.083s) -> MAX DURATION (1.0s).
#
# Processing: m1521_1_cough.wav
# Trimmed Core (1.984s) -> MAX DURATION (1.0s).
#
# Processing: f1223_0_laughter.wav
# Trimmed Core (4.256s) -> MAX DURATION (1.0s).
#
# Processing: m1109_0_cough.wav
# Trimmed Core (2.560s) -> MAX DURATION (1.0s).
#
# Processing: m1699_0_throatclearing.wav
# Trimmed Core (2.496s) -> MAX DURATION (1.0s).
#
# Processing: m2069_1_sigh.wav
#  WARNING: Audio file vs_release_16k/audio_16k/m2069_1_sigh.wav was too quiet (-96). Skipping...
#
# Processing: f3329_0_sniff.wav
# Trimmed Core (3.296s) -> MAX DURATION (1.0s).
#
# Processing: m1394_1_throatclearing.wav
# Trimmed Core (5.184s) -> MAX DURATION (1.0s).
#
# Processing: m0318_0_sneeze.wav
# Trimmed Core (1.344s) -> MAX DURATION (1.0s).
#
# Processing: f1352_0_sneeze.wav
# Trimmed Core (2.965s) -> MAX DURATION (1.0s).
#
# Processing: m2584_0_laughter.wav
# Trimmed Core (1.120s) -> MAX DURATION (1.0s).
#
# Processing: m2591_0_laughter.wav
# Trimmed Core (3.808s) -> MAX DURATION (1.0s).
#
# Processing: m0168_0_throatclearing.wav
# Trimmed Core (3.040s) -> MAX DURATION (1.0s).
#
# Processing: m2214_0_sigh.wav
# Trimmed Core (5.312s) -> MAX DURATION (1.0s).
#
# Processing: f1307_0_sneeze.wav
# Trimmed Core (3.712s) -> MAX DURATION (1.0s).
#
# Processing: f0607_0_sneeze.wav
# Trimmed Core (1.504s) -> MAX DURATION (1.0s).
#
# Processing: m1951_1_laughter.wav
# Trimmed Core (4.864s) -> MAX DURATION (1.0s).
#
# Processing: m1069_0_laughter.wav
# Trimmed Core (4.544s) -> MAX DURATION (1.0s).
#
# Processing: f0320_0_throatclearing.wav
# Trimmed Core (5.035s) -> MAX DURATION (1.0s).
#
# Processing: f2022_0_sigh.wav
# Trimmed Core (2.144s) -> MAX DURATION (1.0s).
#
# Processing: m2820_0_laughter.wav
# Trimmed Core (2.336s) -> MAX DURATION (1.0s).
#
# Processing: m2223_0_sigh.wav
# Trimmed Core (5.205s) -> MAX DURATION (1.0s).
#
# Processing: f2192_0_laughter.wav
# Trimmed Core (4.224s) -> MAX DURATION (1.0s).
#
# Processing: m0366_0_throatclearing.wav
# Trimmed Core (4.160s) -> MAX DURATION (1.0s).
#
# Processing: f2187_0_laughter.wav
# Trimmed Core (1.752s) -> MAX DURATION (1.0s).
#
# Processing: m2627_0_sneeze.wav
# Trimmed Core (1.120s) -> MAX DURATION (1.0s).
#
# Processing: m2208_0_sniff.wav
# Trimmed Core (5.483s) -> MAX DURATION (1.0s).
#
# Processing: f1648_0_sniff.wav
# Trimmed Core (5.440s) -> MAX DURATION (1.0s).
#
# Processing: m0111_0_throatclearing.wav
# Kept natural duration: 0.768s (less than 1.0s max).
#
# Processing: m1497_0_throatclearing.wav
# Trimmed Core (4.576s) -> MAX DURATION (1.0s).
#
# Processing: f0028_0_cough.wav
# Trimmed Core (3.328s) -> MAX DURATION (1.0s).
#
# Processing: m2758_0_sniff.wav
# Trimmed Core (1.376s) -> MAX DURATION (1.0s).
#
# Processing: m0877_0_sigh.wav
# Kept natural duration: 0.992s (less than 1.0s max).
#
# Processing: m1635_0_laughter.wav
# Trimmed Core (9.312s) -> MAX DURATION (1.0s).
#
# Processing: m0395_0_throatclearing.wav
# Trimmed Core (2.240s) -> MAX DURATION (1.0s).
#
# Processing: m1613_0_throatclearing.wav
# Trimmed Core (1.952s) -> MAX DURATION (1.0s).
#
# Processing: f0157_0_throatclearing.wav
# Trimmed Core (4.544s) -> MAX DURATION (1.0s).
#
# Processing: m3138_0_cough.wav
# Trimmed Core (3.136s) -> MAX DURATION (1.0s).
#
# Processing: f0176_0_sneeze.wav
# Trimmed Core (1.440s) -> MAX DURATION (1.0s).
#
# Processing: m2945_0_cough.wav
# Trimmed Core (6.496s) -> MAX DURATION (1.0s).
#
# Processing: f1882_0_sneeze.wav
# Trimmed Core (3.520s) -> MAX DURATION (1.0s).
#
# Processing: m3161_0_laughter.wav
# Trimmed Core (6.240s) -> MAX DURATION (1.0s).
#
# Processing: m1992_0_sniff.wav
# Trimmed Core (3.008s) -> MAX DURATION (1.0s).
#
# Processing: m2541_0_sigh.wav
# Trimmed Core (1.824s) -> MAX DURATION (1.0s).
#
# Processing: m0837_0_sneeze.wav
# Trimmed Core (2.080s) -> MAX DURATION (1.0s).
#
# Processing: m1498_0_sigh.wav
# Trimmed Core (3.552s) -> MAX DURATION (1.0s).
#
# Processing: f1423_0_sneeze.wav
# Trimmed Core (1.312s) -> MAX DURATION (1.0s).
#
# Processing: f1622_0_laughter.wav
# Trimmed Core (4.544s) -> MAX DURATION (1.0s).
#
# Processing: f0485_0_sigh.wav
# Trimmed Core (4.960s) -> MAX DURATION (1.0s).
#
# Processing: m1196_0_sneeze.wav
# Trimmed Core (2.016s) -> MAX DURATION (1.0s).
#
# Processing: f2882_0_sniff.wav
# Trimmed Core (2.848s) -> MAX DURATION (1.0s).
#
# Processing: m1079_0_throatclearing.wav
# Trimmed Core (1.888s) -> MAX DURATION (1.0s).
#
# Processing: m0520_0_sniff.wav
# Trimmed Core (4.640s) -> MAX DURATION (1.0s).
#
# Processing: f2837_0_laughter.wav
# Trimmed Core (8.000s) -> MAX DURATION (1.0s).
#
# Processing: f3112_0_cough.wav
# Trimmed Core (2.011s) -> MAX DURATION (1.0s).
#
# Processing: f2822_0_laughter.wav
# Trimmed Core (5.952s) -> MAX DURATION (1.0s).
#
# Processing: m0552_0_cough.wav
# Trimmed Core (2.528s) -> MAX DURATION (1.0s).
#
# Processing: m2397_0_sniff.wav
# Trimmed Core (7.040s) -> MAX DURATION (1.0s).
#
# Processing: m1468_0_laughter.wav
# Trimmed Core (1.801s) -> MAX DURATION (1.0s).
#
# Processing: f2700_0_cough.wav
# Trimmed Core (5.216s) -> MAX DURATION (1.0s).
#
# Processing: m0469_0_sneeze.wav
# Kept natural duration: 0.896s (less than 1.0s max).
#
# Processing: m3242_0_sigh.wav
# Trimmed Core (1.888s) -> MAX DURATION (1.0s).
#
# Processing: m1169_0_sneeze.wav
# Kept natural duration: 0.576s (less than 1.0s max).
#
# Processing: f2772_0_sniff.wav
# Trimmed Core (5.291s) -> MAX DURATION (1.0s).
#
# Processing: m0070_0_sniff.wav
# Trimmed Core (4.779s) -> MAX DURATION (1.0s).
#
# Processing: m1187_0_sigh.wav
# Trimmed Core (3.200s) -> MAX DURATION (1.0s).
#
# Processing: f1248_0_throatclearing.wav
# Trimmed Core (1.536s) -> MAX DURATION (1.0s).
#
# Processing: m0002_0_cough.wav
# Trimmed Core (2.688s) -> MAX DURATION (1.0s).
#
# Processing: m2190_0_laughter.wav
# Trimmed Core (2.016s) -> MAX DURATION (1.0s).
#
# Processing: f1386_0_sigh.wav
# Trimmed Core (1.856s) -> MAX DURATION (1.0s).
#
# Processing: f2250_0_cough.wav
# Trimmed Core (5.472s) -> MAX DURATION (1.0s).
#
# Processing: m1610_0_cough.wav
# Trimmed Core (1.248s) -> MAX DURATION (1.0s).
#
# Processing: m2648_0_cough.wav
# Trimmed Core (3.296s) -> MAX DURATION (1.0s).
#
# Processing: o0337_0_cough.wav
# Trimmed Core (2.699s) -> MAX DURATION (1.0s).
#
# Processing: f0839_0_throatclearing.wav
# Trimmed Core (2.368s) -> MAX DURATION (1.0s).
#
# Processing: m3028_0_sniff.wav
# Trimmed Core (2.560s) -> MAX DURATION (1.0s).
#
# Processing: m3205_0_sneeze.wav
# Kept natural duration: 0.384s (less than 1.0s max).
#
# Processing: f0468_0_sniff.wav
# Trimmed Core (2.304s) -> MAX DURATION (1.0s).
#
# Processing: f2643_0_laughter.wav
# Trimmed Core (4.512s) -> MAX DURATION (1.0s).
#
# Processing: f2101_0_sigh.wav
# Trimmed Core (1.856s) -> MAX DURATION (1.0s).
#
# Processing: m2318_0_cough.wav
# Trimmed Core (1.760s) -> MAX DURATION (1.0s).
#
# Processing: f3097_1_cough.wav
# Kept natural duration: 0.992s (less than 1.0s max).
#
# Processing: m3250_0_sneeze.wav
# Trimmed Core (1.920s) -> MAX DURATION (1.0s).
#
# Processing: m0100_0_laughter.wav
# Trimmed Core (4.032s) -> MAX DURATION (1.0s).
#
# Processing: f0138_0_sniff.wav
# Trimmed Core (2.592s) -> MAX DURATION (1.0s).
#
# Processing: m0954_0_sigh.wav
# Trimmed Core (3.040s) -> MAX DURATION (1.0s).
#
# Processing: f1949_0_sigh.wav
# Trimmed Core (1.568s) -> MAX DURATION (1.0s).
#
# Processing: f2890_0_sigh.wav
# Kept natural duration: 0.896s (less than 1.0s max).
#
# Processing: f1856_0_laughter.wav
# Trimmed Core (1.952s) -> MAX DURATION (1.0s).
#
# Processing: m2409_0_laughter.wav
# Trimmed Core (3.328s) -> MAX DURATION (1.0s).
#
# Processing: m0160_0_cough.wav
# Trimmed Core (1.632s) -> MAX DURATION (1.0s).
#
# Processing: f2711_0_throatclearing.wav
# Trimmed Core (1.504s) -> MAX DURATION (1.0s).
#
# Processing: f1397_0_cough.wav
# Trimmed Core (8.160s) -> MAX DURATION (1.0s).
#
# Processing: f0928_0_sigh.wav
# Trimmed Core (4.320s) -> MAX DURATION (1.0s).
#
# Processing: f2332_0_cough.wav
# Trimmed Core (4.256s) -> MAX DURATION (1.0s).
#
# Processing: f0585_0_cough.wav
# Trimmed Core (1.888s) -> MAX DURATION (1.0s).
#
# Processing: f3070_0_cough.wav
# Trimmed Core (1.824s) -> MAX DURATION (1.0s).
#
# Processing: m0442_0_sniff.wav
# Trimmed Core (3.861s) -> MAX DURATION (1.0s).
#
# Processing: m0430_0_cough.wav
# Trimmed Core (2.944s) -> MAX DURATION (1.0s).
#
# Processing: m2757_0_throatclearing.wav
# Trimmed Core (2.176s) -> MAX DURATION (1.0s).
#
# Processing: f3002_0_sniff.wav
# Trimmed Core (1.781s) -> MAX DURATION (1.0s).
#
# Processing: f2662_0_cough.wav
# Trimmed Core (1.184s) -> MAX DURATION (1.0s).
#
# Processing: m1841_0_laughter.wav
# Trimmed Core (2.656s) -> MAX DURATION (1.0s).
#
# Processing: m1250_0_sniff.wav
# Trimmed Core (7.253s) -> MAX DURATION (1.0s).
#
# Processing: m1222_0_cough.wav
# Trimmed Core (5.984s) -> MAX DURATION (1.0s).
#
# Processing: f2610_0_sniff.wav
# Trimmed Core (2.848s) -> MAX DURATION (1.0s).
#
# Processing: f1945_0_sniff.wav
# Trimmed Core (2.645s) -> MAX DURATION (1.0s).
#
# Processing: m2654_0_laughter.wav
# Trimmed Core (4.437s) -> MAX DURATION (1.0s).
#
# Processing: f3264_0_throatclearing.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: f0117_0_laughter.wav
# Trimmed Core (1.280s) -> MAX DURATION (1.0s).
#
# Processing: m0940_0_sneeze.wav
# Trimmed Core (2.496s) -> MAX DURATION (1.0s).
#
# Processing: f1949_1_sigh.wav
# Trimmed Core (1.536s) -> MAX DURATION (1.0s).
#
# Processing: m1093_0_sigh.wav
# Trimmed Core (3.437s) -> MAX DURATION (1.0s).
#
# Processing: m0501_0_laughter.wav
# Trimmed Core (4.768s) -> MAX DURATION (1.0s).
#
# Processing: m0514_0_laughter.wav
# Trimmed Core (5.184s) -> MAX DURATION (1.0s).
#
# Processing: f1292_0_sigh.wav
# Trimmed Core (2.400s) -> MAX DURATION (1.0s).
#
# Processing: m0864_0_sniff.wav
# Trimmed Core (4.352s) -> MAX DURATION (1.0s).
#
# Processing: f2257_0_laughter.wav
# Trimmed Core (3.104s) -> MAX DURATION (1.0s).
#
# Processing: m0790_0_sigh.wav
# Trimmed Core (7.680s) -> MAX DURATION (1.0s).
#
# Processing: f2960_0_sneeze.wav
# Kept natural duration: 0.928s (less than 1.0s max).
#
# Processing: f3094_0_sneeze.wav
# Kept natural duration: 0.736s (less than 1.0s max).
#
# Processing: f2594_0_sneeze.wav
# Trimmed Core (3.072s) -> MAX DURATION (1.0s).
#
# Processing: f1511_0_cough.wav
# Trimmed Core (2.624s) -> MAX DURATION (1.0s).
#
# Processing: m2008_0_laughter.wav
# Kept natural duration: 0.832s (less than 1.0s max).
#
# Processing: f0591_0_sigh.wav
# Trimmed Core (6.304s) -> MAX DURATION (1.0s).
#
# Processing: m2559_0_throatclearing.wav
# Kept natural duration: 0.480s (less than 1.0s max).
#
# Processing: m2123_0_sniff.wav
# Trimmed Core (9.216s) -> MAX DURATION (1.0s).
#
# Processing: m2151_0_cough.wav
# Kept natural duration: 0.608s (less than 1.0s max).
#
# Processing: m0794_0_sniff.wav
# Trimmed Core (2.592s) -> MAX DURATION (1.0s).
#
# Processing: m2021_0_sneeze.wav
# Trimmed Core (8.448s) -> MAX DURATION (1.0s).
#
# Processing: f0653_0_cough.wav
# Trimmed Core (6.623s) -> MAX DURATION (1.0s).
#
# Processing: f3099_0_throatclearing.wav
# Trimmed Core (2.976s) -> MAX DURATION (1.0s).
#
# Processing: m2473_0_sniff.wav
# Trimmed Core (4.907s) -> MAX DURATION (1.0s).
#
# Processing: m2401_0_cough.wav
# Trimmed Core (3.424s) -> MAX DURATION (1.0s).
#
# Processing: m2074_0_sneeze.wav
# Trimmed Core (2.144s) -> MAX DURATION (1.0s).
#
# Processing: f1270_0_sneeze.wav
# Trimmed Core (2.261s) -> MAX DURATION (1.0s).
#
# Processing: f0840_0_throatclearing.wav
# Trimmed Core (1.856s) -> MAX DURATION (1.0s).
#
# Processing: m0566_1_sneeze.wav
# Trimmed Core (2.987s) -> MAX DURATION (1.0s).
#
# Processing: f1225_0_sneeze.wav
# Trimmed Core (3.328s) -> MAX DURATION (1.0s).
#
# Processing: f2375_0_throatclearing.wav
# Trimmed Core (2.731s) -> MAX DURATION (1.0s).
#
# Processing: m0806_0_throatclearing.wav
# Trimmed Core (1.664s) -> MAX DURATION (1.0s).
#
# Processing: m0989_0_cough.wav
# Trimmed Core (3.840s) -> MAX DURATION (1.0s).
#
# Processing: m1019_0_sniff.wav
# Trimmed Core (3.413s) -> MAX DURATION (1.0s).
#
# Processing: f0516_0_laughter.wav
# Trimmed Core (3.243s) -> MAX DURATION (1.0s).
#
# Processing: f2102_0_throatclearing.wav
# Trimmed Core (4.544s) -> MAX DURATION (1.0s).
#
# Processing: f2459_0_sniff.wav
# Trimmed Core (2.048s) -> MAX DURATION (1.0s).
#
# Processing: f3239_0_cough.wav
# Trimmed Core (2.976s) -> MAX DURATION (1.0s).
#
# Processing: m1549_0_sniff.wav
# Trimmed Core (2.219s) -> MAX DURATION (1.0s).
#
# Processing: m2255_0_laughter.wav
# Kept natural duration: 0.864s (less than 1.0s max).
#
# Processing: f2386_0_throatclearing.wav
# Trimmed Core (2.528s) -> MAX DURATION (1.0s).
#
# Processing: m2144_0_throatclearing.wav
# Trimmed Core (5.995s) -> MAX DURATION (1.0s).
#
# Processing: m0589_1_laughter.wav
# Trimmed Core (3.424s) -> MAX DURATION (1.0s).
#
# Processing: m0329_0_cough.wav
# Trimmed Core (1.856s) -> MAX DURATION (1.0s).
#
# --- Process Complete ---

# %% [markdown]
# #### Display Sample Audio
#
# Audio should be trimmed, of length [0.2, 1], and not silent

# %%
AUDIO_DIR = "audio/audio_processed"
N_SAMPLES = 25 # The target number of files to sample

# File gathering
all_audio_paths = [
    f for f in glob(os.path.join(AUDIO_DIR, '*.*'))
    if os.path.isfile(f) and f.lower().endswith(('.wav'))
]

num_total_files = len(all_audio_paths)
sampled_files = random.sample(all_audio_paths, N_SAMPLES)

for i, file_path in enumerate(sampled_files):
    filename = os.path.basename(file_path)

    # Display the filename as a header
    print(f"{i+1}. {filename}")

    # Display the in-line audio player widget
    display(Audio(filename=file_path))

    display(Markdown("---"))
# Out:
# 1. f2872_0_cough.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 2. m0023_0_sigh.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 3. f3064_0_laughter.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 4. f2462_0_sigh.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 5. f0061_0_laughter.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 6. m2190_0_sigh.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 7. m3224_0_sniff.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 8. f1480_0_sigh.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 9. m1169_0_throatclearing.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 10. m2727_0_sigh.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 11. m2797_0_sniff.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 12. m3302_0_cough.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 13. m1664_0_laughter.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 14. f0737_0_sniff.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 15. m2790_0_laughter.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 16. m1150_0_sigh.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 17. f1344_0_sigh.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 18. m1920_0_sneeze.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 19. f1803_0_sigh.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 20. f2459_0_laughter.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 21. f3215_0_sigh.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 22. m2341_0_sneeze.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 23. m1823_0_cough.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 24. m2343_0_sniff.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---
# 25. f0689_0_sigh.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---

# %% [markdown]
# ### Create Spectrograms
#
# For our visualization, we want to display each audio clip to the user. We follow a similar style to the Bird Sounds Visualization, using a spectrogram. To make the images look like thin, dark lines on a white background, we aggressively limit the dynamic range.

# %%
def create_sparse_spectrogram_image(audio_filepath, output_image_filepath, sr=16000, n_fft=2048, hop_length=256, n_mels=128, db_range_min=-30, figsize=(2, 2), dpi=100):
    audio, sr = librosa.load(audio_filepath, sr=sr, mono=True)

    # Compute Mel Spectrogram
    S = librosa.feature.melspectrogram(y=audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
    # Convert to log-amplitude (dB). Use np.max(S) as the reference (0 dB)
    S_db = librosa.power_to_db(S, ref=np.max)

    # Aggressive Dynamic Range Compression
    # VMAX is always 0 (loudest point in the clip).
    # VMIN determines what is considered background (white)
    VMAX = 0
    VMIN = db_range_min

    plt.figure(figsize=figsize, dpi=dpi)

    # Use 'gray' colormap (dark patterns on light background) and set the strict VMIN/VMAX range
    librosa.display.specshow(S_db, sr=sr, hop_length=hop_length,
                             x_axis=None, y_axis=None,
                             cmap='Greys',
                             vmin=VMIN,
                             vmax=VMAX)

    plt.tight_layout(pad=0)
    plt.gca().set_axis_off()
    plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
    plt.savefig(output_image_filepath, bbox_inches='tight', pad_inches=0)
    plt.close()

# %%
SOURCE_AUDIO_DIR = "audio/audio_processed"
OUTPUT_IMAGE_DIR = "audio/sparse_spectrograms"

IMAGE_SIZE_PX = 200
IMAGE_DPI = 100
FIG_SIZE_INCHES = IMAGE_SIZE_PX / IMAGE_DPI

# SPECTROGRAM PARAMETERS
# Determines the lowest dB level that will still show up as a pattern (-30 dB for sparse, thin lines)
SPARSENESS_THRESHOLD_DB = -30
# Reduced hop_length for better time resolution (horizontal density)
SPECTROGRAM_HOP_LENGTH = 256

print("--- Starting Sparse Spectrogram Image Generation ---")

os.makedirs(OUTPUT_IMAGE_DIR, exist_ok=True)
print(f"Output Image Directory: {OUTPUT_IMAGE_DIR}")
print(f"Sparseness Threshold (VMIN): {SPARSENESS_THRESHOLD_DB} dB")

for filename in os.listdir(SOURCE_AUDIO_DIR):
    if filename.endswith((".wav")):
        audio_filepath = os.path.join(SOURCE_AUDIO_DIR, filename)
        image_filename = os.path.splitext(filename)[0] + ".png"
        output_image_filepath = os.path.join(OUTPUT_IMAGE_DIR, image_filename)

        create_sparse_spectrogram_image(
            audio_filepath,
            output_image_filepath,
            hop_length=SPECTROGRAM_HOP_LENGTH,
            db_range_min=SPARSENESS_THRESHOLD_DB,
            figsize=(FIG_SIZE_INCHES, FIG_SIZE_INCHES),
            dpi=IMAGE_DPI
        )

print(f"\n--- Sparse Spectrogram Generation Complete ---")
# Out:
# --- Starting Sparse Spectrogram Image Generation ---
# Output Image Directory: audio/sparse_spectrograms
# Sparseness Threshold (VMIN): -30 dB
#
# --- Sparse Spectrogram Generation Complete ---
